# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, LeakyReLU, BatchNormalization
from tensorflow.keras.models import Model
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# Đọc DataFrame 'transaction'
transaction_df = pd.read_csv('../balanced_transaction-from-to-prefix.csv')

# Tạo DataFrame 'data' để lưu kết quả
data_df = pd.DataFrame(columns=['hash', 'image', 'label'])

# Đọc cột 'hash' và 'label'
hash_values = transaction_df['hash']
label_values = transaction_df['label']

# Khởi tạo biến đếm
loop_counter = 1

# Duyệt qua từng giá trị hash và label
for hash_value, label_value in zip(hash_values, label_values):
    # Tạo tên file từ giá trị hash
    filename = f'../ImageData/data/_{hash_value}_data.txt'

    try:
        # Đọc nội dung từ file
        data = np.genfromtxt(filename, delimiter='\t')
        # image = pd.read_csv(filename)

        # Kiểm tra kích thước mảng
        if data.shape == (30, 30):
            # Tạo một hàng mới trong DataFrame 'data'
            new_row = pd.DataFrame({'hash': [hash_value], 'image': [data], 'label': [label_value]})
            data_df = pd.concat([data_df, new_row], ignore_index=True)
        else:
            print(f"Kích thước mảng không phù hợp trong file {filename}")
    except FileNotFoundError:
        print(f"Không tìm thấy file {filename}")

    # In ra lần chạy thứ n của vòng lặp
    print(f"Lần chạy thứ {loop_counter}")
    loop_counter += 1

    # if loop_counter == 4:
    #   break

# In ra DataFrame 'data'
print(data_df.shape)
print(data_df.head(3))
# Out:
# Lần chạy thứ 1
# Lần chạy thứ 2
# Lần chạy thứ 3
# Lần chạy thứ 4
# Lần chạy thứ 5
# Lần chạy thứ 6
# Lần chạy thứ 7
# Lần chạy thứ 8
# Lần chạy thứ 9
# Lần chạy thứ 10
# Lần chạy thứ 11
# Lần chạy thứ 12
# Lần chạy thứ 13
# Lần chạy thứ 14
# Lần chạy thứ 15
# Lần chạy thứ 16
# Lần chạy thứ 17
# Lần chạy thứ 18
# Lần chạy thứ 19
# Lần chạy thứ 20
# Lần chạy thứ 21
# Lần chạy thứ 22
# Lần chạy thứ 23
# Lần chạy thứ 24
# Lần chạy thứ 25
# Lần chạy thứ 26
# Lần chạy thứ 27
# Lần chạy thứ 28
# Lần chạy thứ 29
# Lần chạy thứ 30
# Lần chạy thứ 31
# Lần chạy thứ 32
# Lần chạy thứ 33
# Lần chạy thứ 34
# Lần chạy thứ 35
# Lần chạy thứ 36
# Lần chạy thứ 37
# Lần chạy thứ 38
# Lần chạy thứ 39
# Lần chạy thứ 40
# Lần chạy thứ 41
# Lần chạy thứ 42
# Lần chạy thứ 43
# Lần chạy thứ 44
# Lần chạy thứ 45
# Lần chạy thứ 46
# Lần chạy thứ 47
# Lần chạy thứ 48
# Lần chạy thứ 49
# Lần chạy thứ 50
# Lần chạy thứ 51
# Lần chạy thứ 52
# Lần chạy thứ 53
# Lần chạy thứ 54
# Lần chạy thứ 55
# Lần chạy thứ 56
# Lần chạy thứ 57
# Lần chạy thứ 58
# Lần chạy thứ 59
# Lần chạy thứ 60
# Lần chạy thứ 61
# Lần chạy thứ 62
# Lần chạy thứ 63
# Lần chạy thứ 64
# Lần chạy thứ 65
# Lần chạy thứ 66
# Lần chạy thứ 67
# Lần chạy thứ 68
# Lần chạy thứ 69
# Lần chạy thứ 70
# Lần chạy thứ 71
# Lần chạy thứ 72
# Lần chạy thứ 73
# Lần chạy thứ 74
# Lần chạy thứ 75
# Lần chạy thứ 76
# Lần chạy thứ 77
# Lần chạy thứ 78
# Lần chạy thứ 79
# Lần chạy thứ 80
# Lần chạy thứ 81
# Lần chạy thứ 82
# Lần chạy thứ 83
# Lần chạy thứ 84
# Lần chạy thứ 85
# Lần chạy thứ 86
# Lần chạy thứ 87
# Lần chạy thứ 88
# Lần chạy thứ 89
# Lần chạy thứ 90
# Lần chạy thứ 91
# Lần chạy thứ 92
# Lần chạy thứ 93
# Lần chạy thứ 94
# Lần chạy thứ 95
# Lần chạy thứ 96
# Lần chạy thứ 97
# Lần chạy thứ 98
# Lần chạy thứ 99
# Lần chạy thứ 100
# Lần chạy thứ 101
# Lần chạy thứ 102
# Lần chạy thứ 103
# Lần chạy thứ 104
# Lần chạy thứ 105
# Lần chạy thứ 106
# Lần chạy thứ 107
# Lần chạy thứ 108
# Lần chạy thứ 109
# Lần chạy thứ 110
# Lần chạy thứ 111
# Lần chạy thứ 112
# Lần chạy thứ 113
# Lần chạy thứ 114
# Lần chạy thứ 115
# Lần chạy thứ 116
# Lần chạy thứ 117
# Lần chạy thứ 118
# Lần chạy thứ 119
# Lần chạy thứ 120
# Lần chạy thứ 121
# Lần chạy thứ 122
# Lần chạy thứ 123
# Lần chạy thứ 124
# Lần chạy thứ 125
# Lần chạy thứ 126
# Lần chạy thứ 127
# Lần chạy thứ 128
# Lần chạy thứ 129
# Lần chạy thứ 130
# Lần chạy thứ 131
# Lần chạy thứ 132
# Lần chạy thứ 133
# Lần chạy thứ 134
# Lần chạy thứ 135
# Lần chạy thứ 136
# Lần chạy thứ 137
# Lần chạy thứ 138
# Lần chạy thứ 139
# Lần chạy thứ 140
# Lần chạy thứ 141
# Lần chạy thứ 142
# Lần chạy thứ 143
# Lần chạy thứ 144
# Lần chạy thứ 145
# Lần chạy thứ 146
# Lần chạy thứ 147
# Lần chạy thứ 148
# Lần chạy thứ 149
# Lần chạy thứ 150
# Lần chạy thứ 151
# Lần chạy thứ 152
# Lần chạy thứ 153
# Lần chạy thứ 154
# Lần chạy thứ 155
# Lần chạy thứ 156
# Lần chạy thứ 157
# Lần chạy thứ 158
# Lần chạy thứ 159
# Lần chạy thứ 160
# Lần chạy thứ 161
# Lần chạy thứ 162
# Lần chạy thứ 163
# Lần chạy thứ 164
# Lần chạy thứ 165
# Lần chạy thứ 166
# Lần chạy thứ 167
# Lần chạy thứ 168
# Lần chạy thứ 169
# Lần chạy thứ 170
# Lần chạy thứ 171
# Lần chạy thứ 172
# Lần chạy thứ 173
# Lần chạy thứ 174
# Lần chạy thứ 175
# Lần chạy thứ 176
# Lần chạy thứ 177
# Lần chạy thứ 178
# Lần chạy thứ 179
# Lần chạy thứ 180
# Lần chạy thứ 181
# Lần chạy thứ 182
# Lần chạy thứ 183
# Lần chạy thứ 184
# Lần chạy thứ 185
# Lần chạy thứ 186
# Lần chạy thứ 187
# Lần chạy thứ 188
# Lần chạy thứ 189
# Lần chạy thứ 190
# Lần chạy thứ 191
# Lần chạy thứ 192
# Lần chạy thứ 193
# Lần chạy thứ 194
# Lần chạy thứ 195
# Lần chạy thứ 196
# Lần chạy thứ 197
# Lần chạy thứ 198
# Lần chạy thứ 199
# Lần chạy thứ 200
# Lần chạy thứ 201
# Lần chạy thứ 202
# Lần chạy thứ 203
# Lần chạy thứ 204
# Lần chạy thứ 205
# Lần chạy thứ 206
# Lần chạy thứ 207
# Lần chạy thứ 208
# Lần chạy thứ 209
# Lần chạy thứ 210
# Lần chạy thứ 211
# Lần chạy thứ 212
# Lần chạy thứ 213
# Lần chạy thứ 214
# Lần chạy thứ 215
# Lần chạy thứ 216
# Lần chạy thứ 217
# Lần chạy thứ 218
# Lần chạy thứ 219
# Lần chạy thứ 220
# Lần chạy thứ 221
# Lần chạy thứ 222
# Lần chạy thứ 223
# Lần chạy thứ 224
# Lần chạy thứ 225
# Lần chạy thứ 226
# Lần chạy thứ 227
# Lần chạy thứ 228
# Lần chạy thứ 229
# Lần chạy thứ 230
# Lần chạy thứ 231
# Lần chạy thứ 232
# Lần chạy thứ 233
# Lần chạy thứ 234
# Lần chạy thứ 235
# Lần chạy thứ 236
# Lần chạy thứ 237
# Lần chạy thứ 238
# Lần chạy thứ 239
# Lần chạy thứ 240
# Lần chạy thứ 241
# Lần chạy thứ 242
# Lần chạy thứ 243
# Lần chạy thứ 244
# Lần chạy thứ 245
# Lần chạy thứ 246
# Lần chạy thứ 247
# Lần chạy thứ 248
# Lần chạy thứ 249
# Lần chạy thứ 250
# Lần chạy thứ 251
# Lần chạy thứ 252
# Lần chạy thứ 253
# Lần chạy thứ 254
# Lần chạy thứ 255
# Lần chạy thứ 256
# Lần chạy thứ 257
# Lần chạy thứ 258
# Lần chạy thứ 259
# Lần chạy thứ 260
# Lần chạy thứ 261
# Lần chạy thứ 262
# Lần chạy thứ 263
# Lần chạy thứ 264
# Lần chạy thứ 265
# Lần chạy thứ 266
# Lần chạy thứ 267
# Lần chạy thứ 268
# Lần chạy thứ 269
# Lần chạy thứ 270
# Lần chạy thứ 271
# Lần chạy thứ 272
# Lần chạy thứ 273
# Lần chạy thứ 274
# Lần chạy thứ 275
# Lần chạy thứ 276
# Lần chạy thứ 277
# Lần chạy thứ 278
# Lần chạy thứ 279
# Lần chạy thứ 280
# Lần chạy thứ 281
# Lần chạy thứ 282
# Lần chạy thứ 283
# Lần chạy thứ 284
# Lần chạy thứ 285
# Lần chạy thứ 286
# Lần chạy thứ 287
# Lần chạy thứ 288
# Lần chạy thứ 289
# Lần chạy thứ 290
# Lần chạy thứ 291
# Lần chạy thứ 292
# Lần chạy thứ 293
# Lần chạy thứ 294
# Lần chạy thứ 295
# Lần chạy thứ 296
# Lần chạy thứ 297
# Lần chạy thứ 298
# Lần chạy thứ 299
# Lần chạy thứ 300
# Lần chạy thứ 301
# Lần chạy thứ 302
# Lần chạy thứ 303
# Lần chạy thứ 304
# Lần chạy thứ 305
# Lần chạy thứ 306
# Lần chạy thứ 307
# Lần chạy thứ 308
# Lần chạy thứ 309
# Lần chạy thứ 310
# Lần chạy thứ 311
# Lần chạy thứ 312
# Lần chạy thứ 313
# Lần chạy thứ 314
# Lần chạy thứ 315
# Lần chạy thứ 316
# Lần chạy thứ 317
# Lần chạy thứ 318
# Lần chạy thứ 319
# Lần chạy thứ 320
# Lần chạy thứ 321
# Lần chạy thứ 322
# Lần chạy thứ 323
# Lần chạy thứ 324
# Lần chạy thứ 325
# Lần chạy thứ 326
# Lần chạy thứ 327
# Lần chạy thứ 328
# Lần chạy thứ 329
# Lần chạy thứ 330
# Lần chạy thứ 331
# Lần chạy thứ 332
# Lần chạy thứ 333
# Lần chạy thứ 334
# Lần chạy thứ 335
# Lần chạy thứ 336
# Lần chạy thứ 337
# Lần chạy thứ 338
# Lần chạy thứ 339
# Lần chạy thứ 340
# Lần chạy thứ 341
# Lần chạy thứ 342
# Lần chạy thứ 343
# Lần chạy thứ 344
# Lần chạy thứ 345
# Lần chạy thứ 346
# Lần chạy thứ 347
# Lần chạy thứ 348
# Lần chạy thứ 349
# Lần chạy thứ 350
# Lần chạy thứ 351
# Lần chạy thứ 352
# Lần chạy thứ 353
# Lần chạy thứ 354
# Lần chạy thứ 355
# Lần chạy thứ 356
# Lần chạy thứ 357
# Lần chạy thứ 358
# Lần chạy thứ 359
# Lần chạy thứ 360
# Lần chạy thứ 361
# Lần chạy thứ 362
# Lần chạy thứ 363
# Lần chạy thứ 364
# Lần chạy thứ 365
# Lần chạy thứ 366
# Lần chạy thứ 367
# Lần chạy thứ 368
# Lần chạy thứ 369
# Lần chạy thứ 370
# Lần chạy thứ 371
# Lần chạy thứ 372
# Lần chạy thứ 373
# Lần chạy thứ 374
# Lần chạy thứ 375
# Lần chạy thứ 376
# Lần chạy thứ 377
# Lần chạy thứ 378
# Lần chạy thứ 379
# Lần chạy thứ 380
# Lần chạy thứ 381
# Lần chạy thứ 382
# Lần chạy thứ 383
# Lần chạy thứ 384
# Lần chạy thứ 385
# Lần chạy thứ 386
# Lần chạy thứ 387
# Lần chạy thứ 388
# Lần chạy thứ 389
# Lần chạy thứ 390
# Lần chạy thứ 391
# Lần chạy thứ 392
# Lần chạy thứ 393
# Lần chạy thứ 394
# Lần chạy thứ 395
# Lần chạy thứ 396
# Lần chạy thứ 397
# Lần chạy thứ 398
# Lần chạy thứ 399
# Lần chạy thứ 400
# Lần chạy thứ 401
# Lần chạy thứ 402
# Lần chạy thứ 403
# Lần chạy thứ 404
# Lần chạy thứ 405
# Lần chạy thứ 406
# Lần chạy thứ 407
# Lần chạy thứ 408
# Lần chạy thứ 409
# Lần chạy thứ 410
# Lần chạy thứ 411
# Lần chạy thứ 412
# Lần chạy thứ 413
# Lần chạy thứ 414
# Lần chạy thứ 415
# Lần chạy thứ 416
# Lần chạy thứ 417
# Lần chạy thứ 418
# Lần chạy thứ 419
# Lần chạy thứ 420
# Lần chạy thứ 421
# Lần chạy thứ 422
# Lần chạy thứ 423
# Lần chạy thứ 424
# Lần chạy thứ 425
# Lần chạy thứ 426
# Lần chạy thứ 427
# Lần chạy thứ 428
# Lần chạy thứ 429
# Lần chạy thứ 430
# Lần chạy thứ 431
# Lần chạy thứ 432
# Lần chạy thứ 433
# Lần chạy thứ 434
# Lần chạy thứ 435
# Lần chạy thứ 436
# Lần chạy thứ 437
# Lần chạy thứ 438
# Lần chạy thứ 439
# Lần chạy thứ 440
# Lần chạy thứ 441
# Lần chạy thứ 442
# Lần chạy thứ 443
# Lần chạy thứ 444
# Lần chạy thứ 445
# Lần chạy thứ 446
# Lần chạy thứ 447
# Lần chạy thứ 448
# Lần chạy thứ 449
# Lần chạy thứ 450
# Lần chạy thứ 451
# Lần chạy thứ 452
# Lần chạy thứ 453
# Lần chạy thứ 454
# Lần chạy thứ 455
# Lần chạy thứ 456
# Lần chạy thứ 457
# Lần chạy thứ 458
# Lần chạy thứ 459
# Lần chạy thứ 460
# Lần chạy thứ 461
# Lần chạy thứ 462
# Lần chạy thứ 463
# Lần chạy thứ 464
# Lần chạy thứ 465
# Lần chạy thứ 466
# Lần chạy thứ 467
# Lần chạy thứ 468
# Lần chạy thứ 469
# Lần chạy thứ 470
# Lần chạy thứ 471
# Lần chạy thứ 472
# Lần chạy thứ 473
# Lần chạy thứ 474
# Lần chạy thứ 475
# Lần chạy thứ 476
# Lần chạy thứ 477
# Lần chạy thứ 478
# Lần chạy thứ 479
# Lần chạy thứ 480
# Lần chạy thứ 481
# Lần chạy thứ 482
# Lần chạy thứ 483
# Lần chạy thứ 484
# Lần chạy thứ 485
# Lần chạy thứ 486
# Lần chạy thứ 487
# Lần chạy thứ 488
# Lần chạy thứ 489
# Lần chạy thứ 490
# Lần chạy thứ 491
# Lần chạy thứ 492
# Lần chạy thứ 493
# Lần chạy thứ 494
# Lần chạy thứ 495
# Lần chạy thứ 496
# Lần chạy thứ 497
# Lần chạy thứ 498
# Lần chạy thứ 499
# Lần chạy thứ 500
# Lần chạy thứ 501
# Lần chạy thứ 502
# Lần chạy thứ 503
# Lần chạy thứ 504
# Lần chạy thứ 505
# Lần chạy thứ 506
# Lần chạy thứ 507
# Lần chạy thứ 508
# Lần chạy thứ 509
# Lần chạy thứ 510
# Lần chạy thứ 511
# Lần chạy thứ 512
# Lần chạy thứ 513
# Lần chạy thứ 514
# Lần chạy thứ 515
# Lần chạy thứ 516
# Lần chạy thứ 517
# Lần chạy thứ 518
# Lần chạy thứ 519
# Lần chạy thứ 520
# Lần chạy thứ 521
# Lần chạy thứ 522
# Lần chạy thứ 523
# Lần chạy thứ 524
# Lần chạy thứ 525
# Lần chạy thứ 526
# Lần chạy thứ 527
# Lần chạy thứ 528
# Lần chạy thứ 529
# Lần chạy thứ 530
# Lần chạy thứ 531
# Lần chạy thứ 532
# Lần chạy thứ 533
# Lần chạy thứ 534
# Lần chạy thứ 535
# Lần chạy thứ 536
# Lần chạy thứ 537
# Lần chạy thứ 538
# Lần chạy thứ 539
# Lần chạy thứ 540
# Lần chạy thứ 541
# Lần chạy thứ 542
# Lần chạy thứ 543
# Lần chạy thứ 544
# Lần chạy thứ 545
# Lần chạy thứ 546
# Lần chạy thứ 547
# Lần chạy thứ 548
# Lần chạy thứ 549
# Lần chạy thứ 550
# Lần chạy thứ 551
# Lần chạy thứ 552
# Lần chạy thứ 553
# Lần chạy thứ 554
# Lần chạy thứ 555
# Lần chạy thứ 556
# Lần chạy thứ 557
# Lần chạy thứ 558
# Lần chạy thứ 559
# Lần chạy thứ 560
# Lần chạy thứ 561
# Lần chạy thứ 562
# Lần chạy thứ 563
# Lần chạy thứ 564
# Lần chạy thứ 565
# Lần chạy thứ 566
# Lần chạy thứ 567
# Lần chạy thứ 568
# Lần chạy thứ 569
# Lần chạy thứ 570
# Lần chạy thứ 571
# Lần chạy thứ 572
# Lần chạy thứ 573
# Lần chạy thứ 574
# Lần chạy thứ 575
# Lần chạy thứ 576
# Lần chạy thứ 577
# Lần chạy thứ 578
# Lần chạy thứ 579
# Lần chạy thứ 580
# Lần chạy thứ 581
# Lần chạy thứ 582
# Lần chạy thứ 583
# Lần chạy thứ 584
# Lần chạy thứ 585
# Lần chạy thứ 586
# Lần chạy thứ 587
# Lần chạy thứ 588
# Lần chạy thứ 589
# Lần chạy thứ 590
# Lần chạy thứ 591
# Lần chạy thứ 592
# Lần chạy thứ 593
# Lần chạy thứ 594
# Lần chạy thứ 595
# Lần chạy thứ 596
# Lần chạy thứ 597
# Lần chạy thứ 598
# Lần chạy thứ 599
# Lần chạy thứ 600
# Lần chạy thứ 601
# Lần chạy thứ 602
# Lần chạy thứ 603
# Lần chạy thứ 604
# Lần chạy thứ 605
# Lần chạy thứ 606
# Lần chạy thứ 607
# Lần chạy thứ 608
# Lần chạy thứ 609
# Lần chạy thứ 610
# Lần chạy thứ 611
# Lần chạy thứ 612
# Lần chạy thứ 613
# Lần chạy thứ 614
# Lần chạy thứ 615
# Lần chạy thứ 616
# Lần chạy thứ 617
# Lần chạy thứ 618
# Lần chạy thứ 619
# Lần chạy thứ 620
# Lần chạy thứ 621
# Lần chạy thứ 622
# Lần chạy thứ 623
# Lần chạy thứ 624
# Lần chạy thứ 625
# Lần chạy thứ 626
# Lần chạy thứ 627
# Lần chạy thứ 628
# Lần chạy thứ 629
# Lần chạy thứ 630
# Lần chạy thứ 631
# Lần chạy thứ 632
# Lần chạy thứ 633
# Lần chạy thứ 634
# Lần chạy thứ 635
# Lần chạy thứ 636
# Lần chạy thứ 637
# Lần chạy thứ 638
# Lần chạy thứ 639
# Lần chạy thứ 640
# Lần chạy thứ 641
# Lần chạy thứ 642
# Lần chạy thứ 643
# Lần chạy thứ 644
# Lần chạy thứ 645
# Lần chạy thứ 646
# Lần chạy thứ 647
# Lần chạy thứ 648
# Lần chạy thứ 649
# Lần chạy thứ 650
# Lần chạy thứ 651
# Lần chạy thứ 652
# Lần chạy thứ 653
# Lần chạy thứ 654
# Lần chạy thứ 655
# Lần chạy thứ 656
# Lần chạy thứ 657
# Lần chạy thứ 658
# Lần chạy thứ 659
# Lần chạy thứ 660
# Lần chạy thứ 661
# Lần chạy thứ 662
# Lần chạy thứ 663
# Lần chạy thứ 664
# Lần chạy thứ 665
# Lần chạy thứ 666
# Lần chạy thứ 667
# Lần chạy thứ 668
# Lần chạy thứ 669
# Lần chạy thứ 670
# Lần chạy thứ 671
# Lần chạy thứ 672
# Lần chạy thứ 673
# Lần chạy thứ 674
# Lần chạy thứ 675
# Lần chạy thứ 676
# Lần chạy thứ 677
# Lần chạy thứ 678
# Lần chạy thứ 679
# Lần chạy thứ 680
# Lần chạy thứ 681
# Lần chạy thứ 682
# Lần chạy thứ 683
# Lần chạy thứ 684
# Lần chạy thứ 685
# Lần chạy thứ 686
# Lần chạy thứ 687
# Lần chạy thứ 688
# Lần chạy thứ 689
# Lần chạy thứ 690
# Lần chạy thứ 691
# Lần chạy thứ 692
# Lần chạy thứ 693
# Lần chạy thứ 694
# Lần chạy thứ 695
# Lần chạy thứ 696
# Lần chạy thứ 697
# Lần chạy thứ 698
# Lần chạy thứ 699
# Lần chạy thứ 700
# Lần chạy thứ 701
# Lần chạy thứ 702
# Lần chạy thứ 703
# Lần chạy thứ 704
# Lần chạy thứ 705
# Lần chạy thứ 706
# Lần chạy thứ 707
# Lần chạy thứ 708
# Lần chạy thứ 709
# Lần chạy thứ 710
# Lần chạy thứ 711
# Lần chạy thứ 712
# Lần chạy thứ 713
# Lần chạy thứ 714
# Lần chạy thứ 715
# Lần chạy thứ 716
# Lần chạy thứ 717
# Lần chạy thứ 718
# Lần chạy thứ 719
# Lần chạy thứ 720
# Lần chạy thứ 721
# Lần chạy thứ 722
# Lần chạy thứ 723
# Lần chạy thứ 724
# Lần chạy thứ 725
# Lần chạy thứ 726
# Lần chạy thứ 727
# Lần chạy thứ 728
# Lần chạy thứ 729
# Lần chạy thứ 730
# Lần chạy thứ 731
# Lần chạy thứ 732
# Lần chạy thứ 733
# Lần chạy thứ 734
# Lần chạy thứ 735
# Lần chạy thứ 736
# Lần chạy thứ 737
# Lần chạy thứ 738
# Lần chạy thứ 739
# Lần chạy thứ 740
# Lần chạy thứ 741
# Lần chạy thứ 742
# Lần chạy thứ 743
# Lần chạy thứ 744
# Lần chạy thứ 745
# Lần chạy thứ 746
# Lần chạy thứ 747
# Lần chạy thứ 748
# Lần chạy thứ 749
# Lần chạy thứ 750
# Lần chạy thứ 751
# Lần chạy thứ 752
# Lần chạy thứ 753
# Lần chạy thứ 754
# Lần chạy thứ 755
# Lần chạy thứ 756
# Lần chạy thứ 757
# Lần chạy thứ 758
# Lần chạy thứ 759
# Lần chạy thứ 760
# Lần chạy thứ 761
# Lần chạy thứ 762
# Lần chạy thứ 763
# Lần chạy thứ 764
# Lần chạy thứ 765
# Lần chạy thứ 766
# Lần chạy thứ 767
# Lần chạy thứ 768
# Lần chạy thứ 769
# Lần chạy thứ 770
# Lần chạy thứ 771
# Lần chạy thứ 772
# Lần chạy thứ 773
# Lần chạy thứ 774
# Lần chạy thứ 775
# Lần chạy thứ 776
# Lần chạy thứ 777
# Lần chạy thứ 778
# Lần chạy thứ 779
# Lần chạy thứ 780
# Lần chạy thứ 781
# Lần chạy thứ 782
# Lần chạy thứ 783
# Lần chạy thứ 784
# Lần chạy thứ 785
# Lần chạy thứ 786
# Lần chạy thứ 787
# Lần chạy thứ 788
# Lần chạy thứ 789
# Lần chạy thứ 790
# Lần chạy thứ 791
# Lần chạy thứ 792
# Lần chạy thứ 793
# Lần chạy thứ 794
# Lần chạy thứ 795
# Lần chạy thứ 796
# Lần chạy thứ 797
# Lần chạy thứ 798
# Lần chạy thứ 799
# Lần chạy thứ 800
# Lần chạy thứ 801
# Lần chạy thứ 802
# Lần chạy thứ 803
# Lần chạy thứ 804
# Lần chạy thứ 805
# Lần chạy thứ 806
# Lần chạy thứ 807
# Lần chạy thứ 808
# Lần chạy thứ 809
# Lần chạy thứ 810
# Lần chạy thứ 811
# Lần chạy thứ 812
# Lần chạy thứ 813
# Lần chạy thứ 814
# Lần chạy thứ 815
# Lần chạy thứ 816
# Lần chạy thứ 817
# Lần chạy thứ 818
# Lần chạy thứ 819
# Lần chạy thứ 820
# Lần chạy thứ 821
# Lần chạy thứ 822
# Lần chạy thứ 823
# Lần chạy thứ 824
# Lần chạy thứ 825
# Lần chạy thứ 826
# Lần chạy thứ 827
# Lần chạy thứ 828
# Lần chạy thứ 829
# Lần chạy thứ 830
# Lần chạy thứ 831
# Lần chạy thứ 832
# Lần chạy thứ 833
# Lần chạy thứ 834
# Lần chạy thứ 835
# Lần chạy thứ 836
# Lần chạy thứ 837
# Lần chạy thứ 838
# Lần chạy thứ 839
# Lần chạy thứ 840
# Lần chạy thứ 841
# Lần chạy thứ 842
# Lần chạy thứ 843
# Lần chạy thứ 844
# Lần chạy thứ 845
# Lần chạy thứ 846
# Lần chạy thứ 847
# Lần chạy thứ 848
# Lần chạy thứ 849
# Lần chạy thứ 850
# Lần chạy thứ 851
# Lần chạy thứ 852
# Lần chạy thứ 853
# Lần chạy thứ 854
# Lần chạy thứ 855
# Lần chạy thứ 856
# Lần chạy thứ 857
# Lần chạy thứ 858
# Lần chạy thứ 859
# Lần chạy thứ 860
# Lần chạy thứ 861
# Lần chạy thứ 862
# Lần chạy thứ 863
# Lần chạy thứ 864
# Lần chạy thứ 865
# Lần chạy thứ 866
# Lần chạy thứ 867
# Lần chạy thứ 868
# Lần chạy thứ 869
# Lần chạy thứ 870
# Lần chạy thứ 871
# Lần chạy thứ 872
# Lần chạy thứ 873
# Lần chạy thứ 874
# Lần chạy thứ 875
# Lần chạy thứ 876
# Lần chạy thứ 877
# Lần chạy thứ 878
# Lần chạy thứ 879
# Lần chạy thứ 880
# Lần chạy thứ 881
# Lần chạy thứ 882
# Lần chạy thứ 883
# Lần chạy thứ 884
# Lần chạy thứ 885
# Lần chạy thứ 886
# Lần chạy thứ 887
# Lần chạy thứ 888
# Lần chạy thứ 889
# Lần chạy thứ 890
# Lần chạy thứ 891
# Lần chạy thứ 892
# Lần chạy thứ 893
# Lần chạy thứ 894
# Lần chạy thứ 895
# Lần chạy thứ 896
# Lần chạy thứ 897
# Lần chạy thứ 898
# Lần chạy thứ 899
# Lần chạy thứ 900
# Lần chạy thứ 901
# Lần chạy thứ 902
# Lần chạy thứ 903
# Lần chạy thứ 904
# Lần chạy thứ 905
# Lần chạy thứ 906
# Lần chạy thứ 907
# Lần chạy thứ 908
# Lần chạy thứ 909
# Lần chạy thứ 910
# Lần chạy thứ 911
# Lần chạy thứ 912
# Lần chạy thứ 913
# Lần chạy thứ 914
# Lần chạy thứ 915
# Lần chạy thứ 916
# Lần chạy thứ 917
# Lần chạy thứ 918
# Lần chạy thứ 919
# Lần chạy thứ 920
# Lần chạy thứ 921
# Lần chạy thứ 922
# Lần chạy thứ 923
# Lần chạy thứ 924
# Lần chạy thứ 925
# Lần chạy thứ 926
# Lần chạy thứ 927
# Lần chạy thứ 928
# Lần chạy thứ 929
# Lần chạy thứ 930
# Lần chạy thứ 931
# Lần chạy thứ 932
# Lần chạy thứ 933
# Lần chạy thứ 934
# Lần chạy thứ 935
# Lần chạy thứ 936
# Lần chạy thứ 937
# Lần chạy thứ 938
# Lần chạy thứ 939
# Lần chạy thứ 940
# Lần chạy thứ 941
# Lần chạy thứ 942
# Lần chạy thứ 943
# Lần chạy thứ 944
# Lần chạy thứ 945
# Lần chạy thứ 946
# Lần chạy thứ 947
# Lần chạy thứ 948
# Lần chạy thứ 949
# Lần chạy thứ 950
# Lần chạy thứ 951
# Lần chạy thứ 952
# Lần chạy thứ 953
# Lần chạy thứ 954
# Lần chạy thứ 955
# Lần chạy thứ 956
# Lần chạy thứ 957
# Lần chạy thứ 958
# Lần chạy thứ 959
# Lần chạy thứ 960
# Lần chạy thứ 961
# Lần chạy thứ 962
# Lần chạy thứ 963
# Lần chạy thứ 964
# Lần chạy thứ 965
# Lần chạy thứ 966
# Lần chạy thứ 967
# Lần chạy thứ 968
# Lần chạy thứ 969
# Lần chạy thứ 970
# Lần chạy thứ 971
# Lần chạy thứ 972
# Lần chạy thứ 973
# Lần chạy thứ 974
# Lần chạy thứ 975
# Lần chạy thứ 976
# Lần chạy thứ 977
# Lần chạy thứ 978
# Lần chạy thứ 979
# Lần chạy thứ 980
# Lần chạy thứ 981
# Lần chạy thứ 982
# Lần chạy thứ 983
# Lần chạy thứ 984
# Lần chạy thứ 985
# Lần chạy thứ 986
# Lần chạy thứ 987
# Lần chạy thứ 988
# Lần chạy thứ 989
# Lần chạy thứ 990
# Lần chạy thứ 991
# Lần chạy thứ 992
# Lần chạy thứ 993
# Lần chạy thứ 994
# Lần chạy thứ 995
# Lần chạy thứ 996
# Lần chạy thứ 997
# Lần chạy thứ 998
# Lần chạy thứ 999
# Lần chạy thứ 1000
# Lần chạy thứ 1001
# Lần chạy thứ 1002
# Lần chạy thứ 1003
# Lần chạy thứ 1004
# Lần chạy thứ 1005
# Lần chạy thứ 1006
# Lần chạy thứ 1007
# Lần chạy thứ 1008
# Lần chạy thứ 1009
# Lần chạy thứ 1010
# Lần chạy thứ 1011
# Lần chạy thứ 1012
# Lần chạy thứ 1013
# Lần chạy thứ 1014
# Lần chạy thứ 1015
# Lần chạy thứ 1016
# Lần chạy thứ 1017
# Lần chạy thứ 1018
# Lần chạy thứ 1019
# Lần chạy thứ 1020
# Lần chạy thứ 1021
# Lần chạy thứ 1022
# Lần chạy thứ 1023
# Lần chạy thứ 1024
# Lần chạy thứ 1025
# Lần chạy thứ 1026
# Lần chạy thứ 1027
# Lần chạy thứ 1028
# Lần chạy thứ 1029
# Lần chạy thứ 1030
# Lần chạy thứ 1031
# Lần chạy thứ 1032
# Lần chạy thứ 1033
# Lần chạy thứ 1034
# Lần chạy thứ 1035
# Lần chạy thứ 1036
# Lần chạy thứ 1037
# Lần chạy thứ 1038
# Lần chạy thứ 1039
# Lần chạy thứ 1040
# Lần chạy thứ 1041
# Lần chạy thứ 1042
# Lần chạy thứ 1043
# Lần chạy thứ 1044
# Lần chạy thứ 1045
# Lần chạy thứ 1046
# Lần chạy thứ 1047
# Lần chạy thứ 1048
# Lần chạy thứ 1049
# Lần chạy thứ 1050
# Lần chạy thứ 1051
# Lần chạy thứ 1052
# Lần chạy thứ 1053
# Lần chạy thứ 1054
# Lần chạy thứ 1055
# Lần chạy thứ 1056
# Lần chạy thứ 1057
# Lần chạy thứ 1058
# Lần chạy thứ 1059
# Lần chạy thứ 1060
# Lần chạy thứ 1061
# Lần chạy thứ 1062
# Lần chạy thứ 1063
# Lần chạy thứ 1064
# Lần chạy thứ 1065
# Lần chạy thứ 1066
# Lần chạy thứ 1067
# Lần chạy thứ 1068
# Lần chạy thứ 1069
# Lần chạy thứ 1070
# Lần chạy thứ 1071
# Lần chạy thứ 1072
# Lần chạy thứ 1073
# Lần chạy thứ 1074
# Lần chạy thứ 1075
# Lần chạy thứ 1076
# Lần chạy thứ 1077
# Lần chạy thứ 1078
# Lần chạy thứ 1079
# Lần chạy thứ 1080
# Lần chạy thứ 1081
# Lần chạy thứ 1082
# Lần chạy thứ 1083
# Lần chạy thứ 1084
# Lần chạy thứ 1085
# Lần chạy thứ 1086
# Lần chạy thứ 1087
# Lần chạy thứ 1088
# Lần chạy thứ 1089
# Lần chạy thứ 1090
# Lần chạy thứ 1091
# Lần chạy thứ 1092
# Lần chạy thứ 1093
# Lần chạy thứ 1094
# Lần chạy thứ 1095
# Lần chạy thứ 1096
# Lần chạy thứ 1097
# Lần chạy thứ 1098
# Lần chạy thứ 1099
# Lần chạy thứ 1100
# Lần chạy thứ 1101
# Lần chạy thứ 1102
# Lần chạy thứ 1103
# Lần chạy thứ 1104
# Lần chạy thứ 1105
# Lần chạy thứ 1106
# Lần chạy thứ 1107
# Lần chạy thứ 1108
# Lần chạy thứ 1109
# Lần chạy thứ 1110
# Lần chạy thứ 1111
# Lần chạy thứ 1112
# Lần chạy thứ 1113
# Lần chạy thứ 1114
# Lần chạy thứ 1115
# Lần chạy thứ 1116
# Lần chạy thứ 1117
# Lần chạy thứ 1118
# Lần chạy thứ 1119
# Lần chạy thứ 1120
# Lần chạy thứ 1121
# Lần chạy thứ 1122
# Lần chạy thứ 1123
# Lần chạy thứ 1124
# Lần chạy thứ 1125
# Lần chạy thứ 1126
# Lần chạy thứ 1127
# Lần chạy thứ 1128
# Lần chạy thứ 1129
# Lần chạy thứ 1130
# Lần chạy thứ 1131
# Lần chạy thứ 1132
# Lần chạy thứ 1133
# Lần chạy thứ 1134
# Lần chạy thứ 1135
# Lần chạy thứ 1136
# Lần chạy thứ 1137
# Lần chạy thứ 1138
# Lần chạy thứ 1139
# Lần chạy thứ 1140
# Lần chạy thứ 1141
# Lần chạy thứ 1142
# Lần chạy thứ 1143
# Lần chạy thứ 1144
# Lần chạy thứ 1145
# Lần chạy thứ 1146
# Lần chạy thứ 1147
# Lần chạy thứ 1148
# Lần chạy thứ 1149
# Lần chạy thứ 1150
# Lần chạy thứ 1151
# Lần chạy thứ 1152
# Lần chạy thứ 1153
# Lần chạy thứ 1154
# Lần chạy thứ 1155
# Lần chạy thứ 1156
# Lần chạy thứ 1157
# Lần chạy thứ 1158
# Lần chạy thứ 1159
# Lần chạy thứ 1160
# Lần chạy thứ 1161
# Lần chạy thứ 1162
# Lần chạy thứ 1163
# Lần chạy thứ 1164
# Lần chạy thứ 1165
# Lần chạy thứ 1166
# Lần chạy thứ 1167
# Lần chạy thứ 1168
# Lần chạy thứ 1169
# Lần chạy thứ 1170
# Lần chạy thứ 1171
# Lần chạy thứ 1172
# Lần chạy thứ 1173
# Lần chạy thứ 1174
# Lần chạy thứ 1175
# Lần chạy thứ 1176
# Lần chạy thứ 1177
# Lần chạy thứ 1178
# Lần chạy thứ 1179
# Lần chạy thứ 1180
# Lần chạy thứ 1181
# Lần chạy thứ 1182
# Lần chạy thứ 1183
# Lần chạy thứ 1184
# Lần chạy thứ 1185
# Lần chạy thứ 1186
# Lần chạy thứ 1187
# Lần chạy thứ 1188
# Lần chạy thứ 1189
# Lần chạy thứ 1190
# Lần chạy thứ 1191
# Lần chạy thứ 1192
# Lần chạy thứ 1193
# Lần chạy thứ 1194
# Lần chạy thứ 1195
# Lần chạy thứ 1196
# Lần chạy thứ 1197
# Lần chạy thứ 1198
# Lần chạy thứ 1199
# Lần chạy thứ 1200
# Lần chạy thứ 1201
# Lần chạy thứ 1202
# Lần chạy thứ 1203
# Lần chạy thứ 1204
# Lần chạy thứ 1205
# Lần chạy thứ 1206
# Lần chạy thứ 1207
# Lần chạy thứ 1208
# Lần chạy thứ 1209
# Lần chạy thứ 1210
# Lần chạy thứ 1211
# Lần chạy thứ 1212
# Lần chạy thứ 1213
# Lần chạy thứ 1214
# Lần chạy thứ 1215
# Lần chạy thứ 1216
# Lần chạy thứ 1217
# Lần chạy thứ 1218
# Lần chạy thứ 1219
# Lần chạy thứ 1220
# Lần chạy thứ 1221
# Lần chạy thứ 1222
# Lần chạy thứ 1223
# Lần chạy thứ 1224
# Lần chạy thứ 1225
# Lần chạy thứ 1226
# Lần chạy thứ 1227
# Lần chạy thứ 1228
# Lần chạy thứ 1229
# Lần chạy thứ 1230
# Lần chạy thứ 1231
# Lần chạy thứ 1232
# Lần chạy thứ 1233
# Lần chạy thứ 1234
# Lần chạy thứ 1235
# Lần chạy thứ 1236
# Lần chạy thứ 1237
# Lần chạy thứ 1238
# Lần chạy thứ 1239
# Lần chạy thứ 1240
# Lần chạy thứ 1241
# Lần chạy thứ 1242
# Lần chạy thứ 1243
# Lần chạy thứ 1244
# Lần chạy thứ 1245
# Lần chạy thứ 1246
# Lần chạy thứ 1247
# Lần chạy thứ 1248
# Lần chạy thứ 1249
# Lần chạy thứ 1250
# Lần chạy thứ 1251
# Lần chạy thứ 1252
# Lần chạy thứ 1253
# Lần chạy thứ 1254
# Lần chạy thứ 1255
# Lần chạy thứ 1256
# Lần chạy thứ 1257
# Lần chạy thứ 1258
# Lần chạy thứ 1259
# Lần chạy thứ 1260
# Lần chạy thứ 1261
# Lần chạy thứ 1262
# Lần chạy thứ 1263
# Lần chạy thứ 1264
# Lần chạy thứ 1265
# Lần chạy thứ 1266
# Lần chạy thứ 1267
# Lần chạy thứ 1268
# Lần chạy thứ 1269
# Lần chạy thứ 1270
# Lần chạy thứ 1271
# Lần chạy thứ 1272
# Lần chạy thứ 1273
# Lần chạy thứ 1274
# Lần chạy thứ 1275
# Lần chạy thứ 1276
# Lần chạy thứ 1277
# Lần chạy thứ 1278
# Lần chạy thứ 1279
# Lần chạy thứ 1280
# Lần chạy thứ 1281
# Lần chạy thứ 1282
# Lần chạy thứ 1283
# Lần chạy thứ 1284
# Lần chạy thứ 1285
# Lần chạy thứ 1286
# Lần chạy thứ 1287
# Lần chạy thứ 1288
# Lần chạy thứ 1289
# Lần chạy thứ 1290
# Lần chạy thứ 1291
# Lần chạy thứ 1292
# Lần chạy thứ 1293
# Lần chạy thứ 1294
# Lần chạy thứ 1295
# Lần chạy thứ 1296
# Lần chạy thứ 1297
# Lần chạy thứ 1298
# Lần chạy thứ 1299
# Lần chạy thứ 1300
# Lần chạy thứ 1301
# Lần chạy thứ 1302
# Lần chạy thứ 1303
# Lần chạy thứ 1304
# Lần chạy thứ 1305
# Lần chạy thứ 1306
# Lần chạy thứ 1307
# Lần chạy thứ 1308
# Lần chạy thứ 1309
# Lần chạy thứ 1310
# Lần chạy thứ 1311
# Lần chạy thứ 1312
# Lần chạy thứ 1313
# Lần chạy thứ 1314
# Lần chạy thứ 1315
# Lần chạy thứ 1316
# Lần chạy thứ 1317
# Lần chạy thứ 1318
# Lần chạy thứ 1319
# Lần chạy thứ 1320
# Lần chạy thứ 1321
# Lần chạy thứ 1322
# Lần chạy thứ 1323
# Lần chạy thứ 1324
# Lần chạy thứ 1325
# Lần chạy thứ 1326
# Lần chạy thứ 1327
# Lần chạy thứ 1328
# Lần chạy thứ 1329
# Lần chạy thứ 1330
# Lần chạy thứ 1331
# Lần chạy thứ 1332
# Lần chạy thứ 1333
# Lần chạy thứ 1334
# Lần chạy thứ 1335
# Lần chạy thứ 1336
# Lần chạy thứ 1337
# Lần chạy thứ 1338
# Lần chạy thứ 1339
# Lần chạy thứ 1340
# Lần chạy thứ 1341
# Lần chạy thứ 1342
# Lần chạy thứ 1343
# Lần chạy thứ 1344
# Lần chạy thứ 1345
# Lần chạy thứ 1346
# Lần chạy thứ 1347
# Lần chạy thứ 1348
# Lần chạy thứ 1349
# Lần chạy thứ 1350
# Lần chạy thứ 1351
# Lần chạy thứ 1352
# Lần chạy thứ 1353
# Lần chạy thứ 1354
# Lần chạy thứ 1355
# Lần chạy thứ 1356
# Lần chạy thứ 1357
# Lần chạy thứ 1358
# Lần chạy thứ 1359
# Lần chạy thứ 1360
# Lần chạy thứ 1361
# Lần chạy thứ 1362
# Lần chạy thứ 1363
# Lần chạy thứ 1364
# Lần chạy thứ 1365
# Lần chạy thứ 1366
# Lần chạy thứ 1367
# Lần chạy thứ 1368
# Lần chạy thứ 1369
# Lần chạy thứ 1370
# Lần chạy thứ 1371
# Lần chạy thứ 1372
# Lần chạy thứ 1373
# Lần chạy thứ 1374
# Lần chạy thứ 1375
# Lần chạy thứ 1376
# Lần chạy thứ 1377
# Lần chạy thứ 1378
# Lần chạy thứ 1379
# Lần chạy thứ 1380
# Lần chạy thứ 1381
# Lần chạy thứ 1382
# Lần chạy thứ 1383
# Lần chạy thứ 1384
# Lần chạy thứ 1385
# Lần chạy thứ 1386
# Lần chạy thứ 1387
# Lần chạy thứ 1388
# Lần chạy thứ 1389
# Lần chạy thứ 1390
# Lần chạy thứ 1391
# Lần chạy thứ 1392
# Lần chạy thứ 1393
# Lần chạy thứ 1394
# Lần chạy thứ 1395
# Lần chạy thứ 1396
# Lần chạy thứ 1397
# Lần chạy thứ 1398
# Lần chạy thứ 1399
# Lần chạy thứ 1400
# Lần chạy thứ 1401
# Lần chạy thứ 1402
# Lần chạy thứ 1403
# Lần chạy thứ 1404
# Lần chạy thứ 1405
# Lần chạy thứ 1406
# Lần chạy thứ 1407
# Lần chạy thứ 1408
# Lần chạy thứ 1409
# Lần chạy thứ 1410
# Lần chạy thứ 1411
# Lần chạy thứ 1412
# Lần chạy thứ 1413
# Lần chạy thứ 1414
# Lần chạy thứ 1415
# Lần chạy thứ 1416
# Lần chạy thứ 1417
# Lần chạy thứ 1418
# Lần chạy thứ 1419
# Lần chạy thứ 1420
# Lần chạy thứ 1421
# Lần chạy thứ 1422
# Lần chạy thứ 1423
# Lần chạy thứ 1424
# Lần chạy thứ 1425
# Lần chạy thứ 1426
# Lần chạy thứ 1427
# Lần chạy thứ 1428
# Lần chạy thứ 1429
# Lần chạy thứ 1430
# Lần chạy thứ 1431
# Lần chạy thứ 1432
# Lần chạy thứ 1433
# Lần chạy thứ 1434
# Lần chạy thứ 1435
# Lần chạy thứ 1436
# Lần chạy thứ 1437
# Lần chạy thứ 1438
# Lần chạy thứ 1439
# Lần chạy thứ 1440
# Lần chạy thứ 1441
# Lần chạy thứ 1442
# Lần chạy thứ 1443
# Lần chạy thứ 1444
# Lần chạy thứ 1445
# Lần chạy thứ 1446
# Lần chạy thứ 1447
# Lần chạy thứ 1448
# Lần chạy thứ 1449
# Lần chạy thứ 1450
# Lần chạy thứ 1451
# Lần chạy thứ 1452
# Lần chạy thứ 1453
# Lần chạy thứ 1454
# Lần chạy thứ 1455
# Lần chạy thứ 1456
# Lần chạy thứ 1457
# Lần chạy thứ 1458
# Lần chạy thứ 1459
# Lần chạy thứ 1460
# Lần chạy thứ 1461
# Lần chạy thứ 1462
# Lần chạy thứ 1463
# Lần chạy thứ 1464
# Lần chạy thứ 1465
# Lần chạy thứ 1466
# Lần chạy thứ 1467
# Lần chạy thứ 1468
# Lần chạy thứ 1469
# Lần chạy thứ 1470
# Lần chạy thứ 1471
# Lần chạy thứ 1472
# Lần chạy thứ 1473
# Lần chạy thứ 1474
# Lần chạy thứ 1475
# Lần chạy thứ 1476
# Lần chạy thứ 1477
# Lần chạy thứ 1478
# Lần chạy thứ 1479
# Lần chạy thứ 1480
# Lần chạy thứ 1481
# Lần chạy thứ 1482
# Lần chạy thứ 1483
# Lần chạy thứ 1484
# Lần chạy thứ 1485
# Lần chạy thứ 1486
# Lần chạy thứ 1487
# Lần chạy thứ 1488
# Lần chạy thứ 1489
# Lần chạy thứ 1490
# Lần chạy thứ 1491
# Lần chạy thứ 1492
# Lần chạy thứ 1493
# Lần chạy thứ 1494
# Lần chạy thứ 1495
# Lần chạy thứ 1496
# Lần chạy thứ 1497
# Lần chạy thứ 1498
# Lần chạy thứ 1499
# Lần chạy thứ 1500
# Lần chạy thứ 1501
# Lần chạy thứ 1502
# Lần chạy thứ 1503
# Lần chạy thứ 1504
# Lần chạy thứ 1505
# Lần chạy thứ 1506
# Lần chạy thứ 1507
# Lần chạy thứ 1508
# Lần chạy thứ 1509
# Lần chạy thứ 1510
# Lần chạy thứ 1511
# Lần chạy thứ 1512
# Lần chạy thứ 1513
# Lần chạy thứ 1514
# Lần chạy thứ 1515
# Lần chạy thứ 1516
# Lần chạy thứ 1517
# Lần chạy thứ 1518
# Lần chạy thứ 1519
# Lần chạy thứ 1520
# Lần chạy thứ 1521
# Lần chạy thứ 1522
# Lần chạy thứ 1523
# Lần chạy thứ 1524
# Lần chạy thứ 1525
# Lần chạy thứ 1526
# Lần chạy thứ 1527
# Lần chạy thứ 1528
# Lần chạy thứ 1529
# Lần chạy thứ 1530
# Lần chạy thứ 1531
# Lần chạy thứ 1532
# Lần chạy thứ 1533
# Lần chạy thứ 1534
# Lần chạy thứ 1535
# Lần chạy thứ 1536
# Lần chạy thứ 1537
# Lần chạy thứ 1538
# Lần chạy thứ 1539
# Lần chạy thứ 1540
# Lần chạy thứ 1541
# Lần chạy thứ 1542
# Lần chạy thứ 1543
# Lần chạy thứ 1544
# Lần chạy thứ 1545
# Lần chạy thứ 1546
# Lần chạy thứ 1547
# Lần chạy thứ 1548
# Lần chạy thứ 1549
# Lần chạy thứ 1550
# Lần chạy thứ 1551
# Lần chạy thứ 1552
# Lần chạy thứ 1553
# Lần chạy thứ 1554
# Lần chạy thứ 1555
# Lần chạy thứ 1556
# Lần chạy thứ 1557
# Lần chạy thứ 1558
# Lần chạy thứ 1559
# Lần chạy thứ 1560
# Lần chạy thứ 1561
# Lần chạy thứ 1562
# Lần chạy thứ 1563
# Lần chạy thứ 1564
# Lần chạy thứ 1565
# Lần chạy thứ 1566
# Lần chạy thứ 1567
# Lần chạy thứ 1568
# Lần chạy thứ 1569
# Lần chạy thứ 1570
# Lần chạy thứ 1571
# Lần chạy thứ 1572
# Lần chạy thứ 1573
# Lần chạy thứ 1574
# Lần chạy thứ 1575
# Lần chạy thứ 1576
# Lần chạy thứ 1577
# Lần chạy thứ 1578
# Lần chạy thứ 1579
# Lần chạy thứ 1580
# Lần chạy thứ 1581
# Lần chạy thứ 1582
# Lần chạy thứ 1583
# Lần chạy thứ 1584
# Lần chạy thứ 1585
# Lần chạy thứ 1586
# Lần chạy thứ 1587
# Lần chạy thứ 1588
# Lần chạy thứ 1589
# Lần chạy thứ 1590
# Lần chạy thứ 1591
# Lần chạy thứ 1592
# Lần chạy thứ 1593
# Lần chạy thứ 1594
# Lần chạy thứ 1595
# Lần chạy thứ 1596
# Lần chạy thứ 1597
# Lần chạy thứ 1598
# Lần chạy thứ 1599
# Lần chạy thứ 1600
# Lần chạy thứ 1601
# Lần chạy thứ 1602
# Lần chạy thứ 1603
# Lần chạy thứ 1604
# Lần chạy thứ 1605
# Lần chạy thứ 1606
# Lần chạy thứ 1607
# Lần chạy thứ 1608
# Lần chạy thứ 1609
# Lần chạy thứ 1610
# Lần chạy thứ 1611
# Lần chạy thứ 1612
# Lần chạy thứ 1613
# Lần chạy thứ 1614
# Lần chạy thứ 1615
# Lần chạy thứ 1616
# Lần chạy thứ 1617
# Lần chạy thứ 1618
# Lần chạy thứ 1619
# Lần chạy thứ 1620
# Lần chạy thứ 1621
# Lần chạy thứ 1622
# Lần chạy thứ 1623
# Lần chạy thứ 1624
# Lần chạy thứ 1625
# Lần chạy thứ 1626
# Lần chạy thứ 1627
# Lần chạy thứ 1628
# Lần chạy thứ 1629
# Lần chạy thứ 1630
# Lần chạy thứ 1631
# Lần chạy thứ 1632
# Lần chạy thứ 1633
# Lần chạy thứ 1634
# Lần chạy thứ 1635
# Lần chạy thứ 1636
# Lần chạy thứ 1637
# Lần chạy thứ 1638
# Lần chạy thứ 1639
# Lần chạy thứ 1640
# Lần chạy thứ 1641
# Lần chạy thứ 1642
# Lần chạy thứ 1643
# Lần chạy thứ 1644
# Lần chạy thứ 1645
# Lần chạy thứ 1646
# Lần chạy thứ 1647
# Lần chạy thứ 1648
# Lần chạy thứ 1649
# Lần chạy thứ 1650
# Lần chạy thứ 1651
# Lần chạy thứ 1652
# Lần chạy thứ 1653
# Lần chạy thứ 1654
# Lần chạy thứ 1655
# Lần chạy thứ 1656
# Lần chạy thứ 1657
# Lần chạy thứ 1658
# Lần chạy thứ 1659
# Lần chạy thứ 1660
# Lần chạy thứ 1661
# Lần chạy thứ 1662
# Lần chạy thứ 1663
# Lần chạy thứ 1664
# Lần chạy thứ 1665
# Lần chạy thứ 1666
# Lần chạy thứ 1667
# Lần chạy thứ 1668
# Lần chạy thứ 1669
# Lần chạy thứ 1670
# Lần chạy thứ 1671
# Lần chạy thứ 1672
# Lần chạy thứ 1673
# Lần chạy thứ 1674
# Lần chạy thứ 1675
# Lần chạy thứ 1676
# Lần chạy thứ 1677
# Lần chạy thứ 1678
# Lần chạy thứ 1679
# Lần chạy thứ 1680
# Lần chạy thứ 1681
# Lần chạy thứ 1682
# Lần chạy thứ 1683
# Lần chạy thứ 1684
# Lần chạy thứ 1685
# Lần chạy thứ 1686
# Lần chạy thứ 1687
# Lần chạy thứ 1688
# Lần chạy thứ 1689
# Lần chạy thứ 1690
# Lần chạy thứ 1691
# Lần chạy thứ 1692
# Lần chạy thứ 1693
# Lần chạy thứ 1694
# Lần chạy thứ 1695
# Lần chạy thứ 1696
# Lần chạy thứ 1697
# Lần chạy thứ 1698
# Lần chạy thứ 1699
# Lần chạy thứ 1700
# Lần chạy thứ 1701
# Lần chạy thứ 1702
# Lần chạy thứ 1703
# Lần chạy thứ 1704
# Lần chạy thứ 1705
# Lần chạy thứ 1706
# Lần chạy thứ 1707
# Lần chạy thứ 1708
# Lần chạy thứ 1709
# Lần chạy thứ 1710
# Lần chạy thứ 1711
# Lần chạy thứ 1712
# Lần chạy thứ 1713
# Lần chạy thứ 1714
# Lần chạy thứ 1715
# Lần chạy thứ 1716
# Lần chạy thứ 1717
# Lần chạy thứ 1718
# Lần chạy thứ 1719
# Lần chạy thứ 1720
# Lần chạy thứ 1721
# Lần chạy thứ 1722
# Lần chạy thứ 1723
# Lần chạy thứ 1724
# Lần chạy thứ 1725
# Lần chạy thứ 1726
# Lần chạy thứ 1727
# Lần chạy thứ 1728
# Lần chạy thứ 1729
# Lần chạy thứ 1730
# Lần chạy thứ 1731
# Lần chạy thứ 1732
# Lần chạy thứ 1733
# Lần chạy thứ 1734
# Lần chạy thứ 1735
# Lần chạy thứ 1736
# Lần chạy thứ 1737
# Lần chạy thứ 1738
# Lần chạy thứ 1739
# Lần chạy thứ 1740
# Lần chạy thứ 1741
# Lần chạy thứ 1742
# Lần chạy thứ 1743
# Lần chạy thứ 1744
# Lần chạy thứ 1745
# Lần chạy thứ 1746
# Lần chạy thứ 1747
# Lần chạy thứ 1748
# Lần chạy thứ 1749
# Lần chạy thứ 1750
# Lần chạy thứ 1751
# Lần chạy thứ 1752
# Lần chạy thứ 1753
# Lần chạy thứ 1754
# Lần chạy thứ 1755
# Lần chạy thứ 1756
# Lần chạy thứ 1757
# Lần chạy thứ 1758
# Lần chạy thứ 1759
# Lần chạy thứ 1760
# Lần chạy thứ 1761
# Lần chạy thứ 1762
# Lần chạy thứ 1763
# Lần chạy thứ 1764
# Lần chạy thứ 1765
# Lần chạy thứ 1766
# Lần chạy thứ 1767
# Lần chạy thứ 1768
# Lần chạy thứ 1769
# Lần chạy thứ 1770
# Lần chạy thứ 1771
# Lần chạy thứ 1772
# Lần chạy thứ 1773
# Lần chạy thứ 1774
# Lần chạy thứ 1775
# Lần chạy thứ 1776
# Lần chạy thứ 1777
# Lần chạy thứ 1778
# Lần chạy thứ 1779
# Lần chạy thứ 1780
# Lần chạy thứ 1781
# Lần chạy thứ 1782
# Lần chạy thứ 1783
# Lần chạy thứ 1784
# Lần chạy thứ 1785
# Lần chạy thứ 1786
# Lần chạy thứ 1787
# Lần chạy thứ 1788
# Lần chạy thứ 1789
# Lần chạy thứ 1790
# Lần chạy thứ 1791
# Lần chạy thứ 1792
# Lần chạy thứ 1793
# Lần chạy thứ 1794
# Lần chạy thứ 1795
# Lần chạy thứ 1796
# Lần chạy thứ 1797
# Lần chạy thứ 1798
# Lần chạy thứ 1799
# Lần chạy thứ 1800
# Lần chạy thứ 1801
# Lần chạy thứ 1802
# Lần chạy thứ 1803
# Lần chạy thứ 1804
# Lần chạy thứ 1805
# Lần chạy thứ 1806
# Lần chạy thứ 1807
# Lần chạy thứ 1808
# Lần chạy thứ 1809
# Lần chạy thứ 1810
# Lần chạy thứ 1811
# Lần chạy thứ 1812
# Lần chạy thứ 1813
# Lần chạy thứ 1814
# Lần chạy thứ 1815
# Lần chạy thứ 1816
# Lần chạy thứ 1817
# Lần chạy thứ 1818
# Lần chạy thứ 1819
# Lần chạy thứ 1820
# Lần chạy thứ 1821
# Lần chạy thứ 1822
# Lần chạy thứ 1823
# Lần chạy thứ 1824
# Lần chạy thứ 1825
# Lần chạy thứ 1826
# Lần chạy thứ 1827
# Lần chạy thứ 1828
# Lần chạy thứ 1829
# Lần chạy thứ 1830
# Lần chạy thứ 1831
# Lần chạy thứ 1832
# Lần chạy thứ 1833
# Lần chạy thứ 1834
# Lần chạy thứ 1835
# Lần chạy thứ 1836
# Lần chạy thứ 1837
# Lần chạy thứ 1838
# Lần chạy thứ 1839
# Lần chạy thứ 1840
# Lần chạy thứ 1841
# Lần chạy thứ 1842
# Lần chạy thứ 1843
# Lần chạy thứ 1844
# Lần chạy thứ 1845
# Lần chạy thứ 1846
# Lần chạy thứ 1847
# Lần chạy thứ 1848
# Lần chạy thứ 1849
# Lần chạy thứ 1850
# Lần chạy thứ 1851
# Lần chạy thứ 1852
# Lần chạy thứ 1853
# Lần chạy thứ 1854
# Lần chạy thứ 1855
# Lần chạy thứ 1856
# Lần chạy thứ 1857
# Lần chạy thứ 1858
# Lần chạy thứ 1859
# Lần chạy thứ 1860
# Lần chạy thứ 1861
# Lần chạy thứ 1862
# Lần chạy thứ 1863
# Lần chạy thứ 1864
# Lần chạy thứ 1865
# Lần chạy thứ 1866
# Lần chạy thứ 1867
# Lần chạy thứ 1868
# Lần chạy thứ 1869
# Lần chạy thứ 1870
# Lần chạy thứ 1871
# Lần chạy thứ 1872
# Lần chạy thứ 1873
# Lần chạy thứ 1874
# Lần chạy thứ 1875
# Lần chạy thứ 1876
# Lần chạy thứ 1877
# Lần chạy thứ 1878
# Lần chạy thứ 1879
# Lần chạy thứ 1880
# Lần chạy thứ 1881
# Lần chạy thứ 1882
# Lần chạy thứ 1883
# Lần chạy thứ 1884
# Lần chạy thứ 1885
# Lần chạy thứ 1886
# Lần chạy thứ 1887
# Lần chạy thứ 1888
# Lần chạy thứ 1889
# Lần chạy thứ 1890
# Lần chạy thứ 1891
# Lần chạy thứ 1892
# Lần chạy thứ 1893
# Lần chạy thứ 1894
# Lần chạy thứ 1895
# Lần chạy thứ 1896
# Lần chạy thứ 1897
# Lần chạy thứ 1898
# Lần chạy thứ 1899
# Lần chạy thứ 1900
# Lần chạy thứ 1901
# Lần chạy thứ 1902
# Lần chạy thứ 1903
# Lần chạy thứ 1904
# Lần chạy thứ 1905
# Lần chạy thứ 1906
# Lần chạy thứ 1907
# Lần chạy thứ 1908
# Lần chạy thứ 1909
# Lần chạy thứ 1910
# Lần chạy thứ 1911
# Lần chạy thứ 1912
# Lần chạy thứ 1913
# Lần chạy thứ 1914
# Lần chạy thứ 1915
# Lần chạy thứ 1916
# Lần chạy thứ 1917
# Lần chạy thứ 1918
# Lần chạy thứ 1919
# Lần chạy thứ 1920
# Lần chạy thứ 1921
# Lần chạy thứ 1922
# Lần chạy thứ 1923
# Lần chạy thứ 1924
# Lần chạy thứ 1925
# Lần chạy thứ 1926
# Lần chạy thứ 1927
# Lần chạy thứ 1928
# Lần chạy thứ 1929
# Lần chạy thứ 1930
# Lần chạy thứ 1931
# Lần chạy thứ 1932
# Lần chạy thứ 1933
# Lần chạy thứ 1934
# Lần chạy thứ 1935
# Lần chạy thứ 1936
# Lần chạy thứ 1937
# Lần chạy thứ 1938
# Lần chạy thứ 1939
# Lần chạy thứ 1940
# Lần chạy thứ 1941
# Lần chạy thứ 1942
# Lần chạy thứ 1943
# Lần chạy thứ 1944
# Lần chạy thứ 1945
# Lần chạy thứ 1946
# Lần chạy thứ 1947
# Lần chạy thứ 1948
# Lần chạy thứ 1949
# Lần chạy thứ 1950
# Lần chạy thứ 1951
# Lần chạy thứ 1952
# Lần chạy thứ 1953
# Lần chạy thứ 1954
# Lần chạy thứ 1955
# Lần chạy thứ 1956
# Lần chạy thứ 1957
# Lần chạy thứ 1958
# Lần chạy thứ 1959
# Lần chạy thứ 1960
# Lần chạy thứ 1961
# Lần chạy thứ 1962
# Lần chạy thứ 1963
# Lần chạy thứ 1964
# Lần chạy thứ 1965
# Lần chạy thứ 1966
# Lần chạy thứ 1967
# Lần chạy thứ 1968
# Lần chạy thứ 1969
# Lần chạy thứ 1970
# Lần chạy thứ 1971
# Lần chạy thứ 1972
# Lần chạy thứ 1973
# Lần chạy thứ 1974
# Lần chạy thứ 1975
# Lần chạy thứ 1976
# Lần chạy thứ 1977
# Lần chạy thứ 1978
# Lần chạy thứ 1979
# Lần chạy thứ 1980
# Lần chạy thứ 1981
# Lần chạy thứ 1982
# Lần chạy thứ 1983
# Lần chạy thứ 1984
# Lần chạy thứ 1985
# Lần chạy thứ 1986
# Lần chạy thứ 1987
# Lần chạy thứ 1988
# Lần chạy thứ 1989
# Lần chạy thứ 1990
# Lần chạy thứ 1991
# Lần chạy thứ 1992
# Lần chạy thứ 1993
# Lần chạy thứ 1994
# Lần chạy thứ 1995
# Lần chạy thứ 1996
# Lần chạy thứ 1997
# Lần chạy thứ 1998
# Lần chạy thứ 1999
# Lần chạy thứ 2000
# Lần chạy thứ 2001
# Lần chạy thứ 2002
# Lần chạy thứ 2003
# Lần chạy thứ 2004
# Lần chạy thứ 2005
# Lần chạy thứ 2006
# Lần chạy thứ 2007
# Lần chạy thứ 2008
# Lần chạy thứ 2009
# Lần chạy thứ 2010
# Lần chạy thứ 2011
# Lần chạy thứ 2012
# Lần chạy thứ 2013
# Lần chạy thứ 2014
# Lần chạy thứ 2015
# Lần chạy thứ 2016
# Lần chạy thứ 2017
# Lần chạy thứ 2018
# Lần chạy thứ 2019
# Lần chạy thứ 2020
# Lần chạy thứ 2021
# Lần chạy thứ 2022
# Lần chạy thứ 2023
# Lần chạy thứ 2024
# Lần chạy thứ 2025
# Lần chạy thứ 2026
# Lần chạy thứ 2027
# Lần chạy thứ 2028
# Lần chạy thứ 2029
# Lần chạy thứ 2030
# Lần chạy thứ 2031
# Lần chạy thứ 2032
# Lần chạy thứ 2033
# Lần chạy thứ 2034
# Lần chạy thứ 2035
# Lần chạy thứ 2036
# Lần chạy thứ 2037
# Lần chạy thứ 2038
# Lần chạy thứ 2039
# Lần chạy thứ 2040
# Lần chạy thứ 2041
# Lần chạy thứ 2042
# Lần chạy thứ 2043
# Lần chạy thứ 2044
# Lần chạy thứ 2045
# Lần chạy thứ 2046
# Lần chạy thứ 2047
# Lần chạy thứ 2048
# Lần chạy thứ 2049
# Lần chạy thứ 2050
# Lần chạy thứ 2051
# Lần chạy thứ 2052
# Lần chạy thứ 2053
# Lần chạy thứ 2054
# Lần chạy thứ 2055
# Lần chạy thứ 2056
# Lần chạy thứ 2057
# Lần chạy thứ 2058
# Lần chạy thứ 2059
# Lần chạy thứ 2060
# Lần chạy thứ 2061
# Lần chạy thứ 2062
# Lần chạy thứ 2063
# Lần chạy thứ 2064
# Lần chạy thứ 2065
# Lần chạy thứ 2066
# Lần chạy thứ 2067
# Lần chạy thứ 2068
# Lần chạy thứ 2069
# Lần chạy thứ 2070
# Lần chạy thứ 2071
# Lần chạy thứ 2072
# Lần chạy thứ 2073
# Lần chạy thứ 2074
# Lần chạy thứ 2075
# Lần chạy thứ 2076
# Lần chạy thứ 2077
# Lần chạy thứ 2078
# Lần chạy thứ 2079
# Lần chạy thứ 2080
# Lần chạy thứ 2081
# Lần chạy thứ 2082
# Lần chạy thứ 2083
# Lần chạy thứ 2084
# Lần chạy thứ 2085
# Lần chạy thứ 2086
# Lần chạy thứ 2087
# Lần chạy thứ 2088
# Lần chạy thứ 2089
# Lần chạy thứ 2090
# Lần chạy thứ 2091
# Lần chạy thứ 2092
# Lần chạy thứ 2093
# Lần chạy thứ 2094
# Lần chạy thứ 2095
# Lần chạy thứ 2096
# Lần chạy thứ 2097
# Lần chạy thứ 2098
# Lần chạy thứ 2099
# Lần chạy thứ 2100
# Lần chạy thứ 2101
# Lần chạy thứ 2102
# Lần chạy thứ 2103
# Lần chạy thứ 2104
# Lần chạy thứ 2105
# Lần chạy thứ 2106
# Lần chạy thứ 2107
# Lần chạy thứ 2108
# Lần chạy thứ 2109
# Lần chạy thứ 2110
# Lần chạy thứ 2111
# Lần chạy thứ 2112
# Lần chạy thứ 2113
# Lần chạy thứ 2114
# Lần chạy thứ 2115
# Lần chạy thứ 2116
# Lần chạy thứ 2117
# Lần chạy thứ 2118
# Lần chạy thứ 2119
# Lần chạy thứ 2120
# Lần chạy thứ 2121
# Lần chạy thứ 2122
# Lần chạy thứ 2123
# Lần chạy thứ 2124
# Lần chạy thứ 2125
# Lần chạy thứ 2126
# Lần chạy thứ 2127
# Lần chạy thứ 2128
# Lần chạy thứ 2129
# Lần chạy thứ 2130
# Lần chạy thứ 2131
# Lần chạy thứ 2132
# Lần chạy thứ 2133
# Lần chạy thứ 2134
# Lần chạy thứ 2135
# Lần chạy thứ 2136
# Lần chạy thứ 2137
# Lần chạy thứ 2138
# Lần chạy thứ 2139
# Lần chạy thứ 2140
# Lần chạy thứ 2141
# Lần chạy thứ 2142
# Lần chạy thứ 2143
# Lần chạy thứ 2144
# Lần chạy thứ 2145
# Lần chạy thứ 2146
# Lần chạy thứ 2147
# Lần chạy thứ 2148
# Lần chạy thứ 2149
# Lần chạy thứ 2150
# Lần chạy thứ 2151
# Lần chạy thứ 2152
# Lần chạy thứ 2153
# Lần chạy thứ 2154
# Lần chạy thứ 2155
# Lần chạy thứ 2156
# Lần chạy thứ 2157
# Lần chạy thứ 2158
# Lần chạy thứ 2159
# Lần chạy thứ 2160
# Lần chạy thứ 2161
# Lần chạy thứ 2162
# Lần chạy thứ 2163
# Lần chạy thứ 2164
# Lần chạy thứ 2165
# Lần chạy thứ 2166
# Lần chạy thứ 2167
# Lần chạy thứ 2168
# Lần chạy thứ 2169
# Lần chạy thứ 2170
# Lần chạy thứ 2171
# Lần chạy thứ 2172
# Lần chạy thứ 2173
# Lần chạy thứ 2174
# Lần chạy thứ 2175
# Lần chạy thứ 2176
# Lần chạy thứ 2177
# Lần chạy thứ 2178
# Lần chạy thứ 2179
# Lần chạy thứ 2180
# Lần chạy thứ 2181
# Lần chạy thứ 2182
# Lần chạy thứ 2183
# Lần chạy thứ 2184
# Lần chạy thứ 2185
# Lần chạy thứ 2186
# Lần chạy thứ 2187
# Lần chạy thứ 2188
# Lần chạy thứ 2189
# Lần chạy thứ 2190
# Lần chạy thứ 2191
# Lần chạy thứ 2192
# Lần chạy thứ 2193
# Lần chạy thứ 2194
# Lần chạy thứ 2195
# Lần chạy thứ 2196
# Lần chạy thứ 2197
# Lần chạy thứ 2198
# Lần chạy thứ 2199
# Lần chạy thứ 2200
# Lần chạy thứ 2201
# Lần chạy thứ 2202
# Lần chạy thứ 2203
# Lần chạy thứ 2204
# Lần chạy thứ 2205
# Lần chạy thứ 2206
# Lần chạy thứ 2207
# Lần chạy thứ 2208
# Lần chạy thứ 2209
# Lần chạy thứ 2210
# Lần chạy thứ 2211
# Lần chạy thứ 2212
# Lần chạy thứ 2213
# Lần chạy thứ 2214
# Lần chạy thứ 2215
# Lần chạy thứ 2216
# Lần chạy thứ 2217
# Lần chạy thứ 2218
# Lần chạy thứ 2219
# Lần chạy thứ 2220
# Lần chạy thứ 2221
# Lần chạy thứ 2222
# Lần chạy thứ 2223
# Lần chạy thứ 2224
# Lần chạy thứ 2225
# Lần chạy thứ 2226
# Lần chạy thứ 2227
# Lần chạy thứ 2228
# Lần chạy thứ 2229
# Lần chạy thứ 2230
# Lần chạy thứ 2231
# Lần chạy thứ 2232
# Lần chạy thứ 2233
# Lần chạy thứ 2234
# Lần chạy thứ 2235
# Lần chạy thứ 2236
# Lần chạy thứ 2237
# Lần chạy thứ 2238
# Lần chạy thứ 2239
# Lần chạy thứ 2240
# Lần chạy thứ 2241
# Lần chạy thứ 2242
# Lần chạy thứ 2243
# Lần chạy thứ 2244
# Lần chạy thứ 2245
# Lần chạy thứ 2246
# Lần chạy thứ 2247
# Lần chạy thứ 2248
# Lần chạy thứ 2249
# Lần chạy thứ 2250
# Lần chạy thứ 2251
# Lần chạy thứ 2252
# Lần chạy thứ 2253
# Lần chạy thứ 2254
# Lần chạy thứ 2255
# Lần chạy thứ 2256
# Lần chạy thứ 2257
# Lần chạy thứ 2258
# Lần chạy thứ 2259
# Lần chạy thứ 2260
# Lần chạy thứ 2261
# Lần chạy thứ 2262
# Lần chạy thứ 2263
# Lần chạy thứ 2264
# Lần chạy thứ 2265
# Lần chạy thứ 2266
# Lần chạy thứ 2267
# Lần chạy thứ 2268
# Lần chạy thứ 2269
# Lần chạy thứ 2270
# Lần chạy thứ 2271
# Lần chạy thứ 2272
# Lần chạy thứ 2273
# Lần chạy thứ 2274
# Lần chạy thứ 2275
# Lần chạy thứ 2276
# Lần chạy thứ 2277
# Lần chạy thứ 2278
# Lần chạy thứ 2279
# Lần chạy thứ 2280
# Lần chạy thứ 2281
# Lần chạy thứ 2282
# Lần chạy thứ 2283
# Lần chạy thứ 2284
# Lần chạy thứ 2285
# Lần chạy thứ 2286
# Lần chạy thứ 2287
# Lần chạy thứ 2288
# Lần chạy thứ 2289
# Lần chạy thứ 2290
# Lần chạy thứ 2291
# Lần chạy thứ 2292
# Lần chạy thứ 2293
# Lần chạy thứ 2294
# Lần chạy thứ 2295
# Lần chạy thứ 2296
# Lần chạy thứ 2297
# Lần chạy thứ 2298
# Lần chạy thứ 2299
# Lần chạy thứ 2300
# Lần chạy thứ 2301
# Lần chạy thứ 2302
# Lần chạy thứ 2303
# Lần chạy thứ 2304
# Lần chạy thứ 2305
# Lần chạy thứ 2306
# Lần chạy thứ 2307
# Lần chạy thứ 2308
# Lần chạy thứ 2309
# Lần chạy thứ 2310
# Lần chạy thứ 2311
# Lần chạy thứ 2312
# Lần chạy thứ 2313
# Lần chạy thứ 2314
# Lần chạy thứ 2315
# Lần chạy thứ 2316
# Lần chạy thứ 2317
# Lần chạy thứ 2318
# Lần chạy thứ 2319
# Lần chạy thứ 2320
# Lần chạy thứ 2321
# Lần chạy thứ 2322
# Lần chạy thứ 2323
# Lần chạy thứ 2324
# Lần chạy thứ 2325
# Lần chạy thứ 2326
# Lần chạy thứ 2327
# Lần chạy thứ 2328
# Lần chạy thứ 2329
# Lần chạy thứ 2330
# Lần chạy thứ 2331
# Lần chạy thứ 2332
# Lần chạy thứ 2333
# Lần chạy thứ 2334
# Lần chạy thứ 2335
# Lần chạy thứ 2336
# Lần chạy thứ 2337
# Lần chạy thứ 2338
# Lần chạy thứ 2339
# Lần chạy thứ 2340
# Lần chạy thứ 2341
# Lần chạy thứ 2342
# Lần chạy thứ 2343
# Lần chạy thứ 2344
# Lần chạy thứ 2345
# Lần chạy thứ 2346
# Lần chạy thứ 2347
# Lần chạy thứ 2348
# Lần chạy thứ 2349
# Lần chạy thứ 2350
# Lần chạy thứ 2351
# Lần chạy thứ 2352
# Lần chạy thứ 2353
# Lần chạy thứ 2354
# Lần chạy thứ 2355
# Lần chạy thứ 2356
# Lần chạy thứ 2357
# Lần chạy thứ 2358
# Lần chạy thứ 2359
# Lần chạy thứ 2360
# Lần chạy thứ 2361
# Lần chạy thứ 2362
# Lần chạy thứ 2363
# Lần chạy thứ 2364
# Lần chạy thứ 2365
# Lần chạy thứ 2366
# Lần chạy thứ 2367
# Lần chạy thứ 2368
# Lần chạy thứ 2369
# Lần chạy thứ 2370
# Lần chạy thứ 2371
# Lần chạy thứ 2372
# Lần chạy thứ 2373
# Lần chạy thứ 2374
# Lần chạy thứ 2375
# Lần chạy thứ 2376
# Lần chạy thứ 2377
# Lần chạy thứ 2378
# Lần chạy thứ 2379
# Lần chạy thứ 2380
# Lần chạy thứ 2381
# Lần chạy thứ 2382
# Lần chạy thứ 2383
# Lần chạy thứ 2384
# Lần chạy thứ 2385
# Lần chạy thứ 2386
# Lần chạy thứ 2387
# Lần chạy thứ 2388
# Lần chạy thứ 2389
# Lần chạy thứ 2390
# Lần chạy thứ 2391
# Lần chạy thứ 2392
# Lần chạy thứ 2393
# Lần chạy thứ 2394
# Lần chạy thứ 2395
# Lần chạy thứ 2396
# Lần chạy thứ 2397
# Lần chạy thứ 2398
# Lần chạy thứ 2399
# Lần chạy thứ 2400
# Lần chạy thứ 2401
# Lần chạy thứ 2402
# Lần chạy thứ 2403
# Lần chạy thứ 2404
# Lần chạy thứ 2405
# Lần chạy thứ 2406
# Lần chạy thứ 2407
# Lần chạy thứ 2408
# Lần chạy thứ 2409
# Lần chạy thứ 2410
# Lần chạy thứ 2411
# Lần chạy thứ 2412
# Lần chạy thứ 2413
# Lần chạy thứ 2414
# Lần chạy thứ 2415
# Lần chạy thứ 2416
# Lần chạy thứ 2417
# Lần chạy thứ 2418
# Lần chạy thứ 2419
# Lần chạy thứ 2420
# Lần chạy thứ 2421
# Lần chạy thứ 2422
# Lần chạy thứ 2423
# Lần chạy thứ 2424
# Lần chạy thứ 2425
# Lần chạy thứ 2426
# Lần chạy thứ 2427
# Lần chạy thứ 2428
# Lần chạy thứ 2429
# Lần chạy thứ 2430
# Lần chạy thứ 2431
# Lần chạy thứ 2432
# Lần chạy thứ 2433
# Lần chạy thứ 2434
# Lần chạy thứ 2435
# Lần chạy thứ 2436
# Lần chạy thứ 2437
# Lần chạy thứ 2438
# Lần chạy thứ 2439
# Lần chạy thứ 2440
# Lần chạy thứ 2441
# Lần chạy thứ 2442
# Lần chạy thứ 2443
# Lần chạy thứ 2444
# Lần chạy thứ 2445
# Lần chạy thứ 2446
# Lần chạy thứ 2447
# Lần chạy thứ 2448
# Lần chạy thứ 2449
# Lần chạy thứ 2450
# Lần chạy thứ 2451
# Lần chạy thứ 2452
# Lần chạy thứ 2453
# Lần chạy thứ 2454
# Lần chạy thứ 2455
# Lần chạy thứ 2456
# Lần chạy thứ 2457
# Lần chạy thứ 2458
# Lần chạy thứ 2459
# Lần chạy thứ 2460
# Lần chạy thứ 2461
# Lần chạy thứ 2462
# Lần chạy thứ 2463
# Lần chạy thứ 2464
# Lần chạy thứ 2465
# Lần chạy thứ 2466
# Lần chạy thứ 2467
# Lần chạy thứ 2468
# Lần chạy thứ 2469
# Lần chạy thứ 2470
# Lần chạy thứ 2471
# Lần chạy thứ 2472
# Lần chạy thứ 2473
# Lần chạy thứ 2474
# Lần chạy thứ 2475
# Lần chạy thứ 2476
# Lần chạy thứ 2477
# Lần chạy thứ 2478
# Lần chạy thứ 2479
# Lần chạy thứ 2480
# Lần chạy thứ 2481
# Lần chạy thứ 2482
# Lần chạy thứ 2483
# Lần chạy thứ 2484
# Lần chạy thứ 2485
# Lần chạy thứ 2486
# Lần chạy thứ 2487
# Lần chạy thứ 2488
# Lần chạy thứ 2489
# Lần chạy thứ 2490
# Lần chạy thứ 2491
# Lần chạy thứ 2492
# Lần chạy thứ 2493
# Lần chạy thứ 2494
# Lần chạy thứ 2495
# Lần chạy thứ 2496
# Lần chạy thứ 2497
# Lần chạy thứ 2498
# Lần chạy thứ 2499
# Lần chạy thứ 2500
# Lần chạy thứ 2501
# Lần chạy thứ 2502
# Lần chạy thứ 2503
# Lần chạy thứ 2504
# Lần chạy thứ 2505
# Lần chạy thứ 2506
# Lần chạy thứ 2507
# Lần chạy thứ 2508
# Lần chạy thứ 2509
# Lần chạy thứ 2510
# Lần chạy thứ 2511
# Lần chạy thứ 2512
# Lần chạy thứ 2513
# Lần chạy thứ 2514
# Lần chạy thứ 2515
# Lần chạy thứ 2516
# Lần chạy thứ 2517
# Lần chạy thứ 2518
# Lần chạy thứ 2519
# Lần chạy thứ 2520
# Lần chạy thứ 2521
# Lần chạy thứ 2522
# Lần chạy thứ 2523
# Lần chạy thứ 2524
# Lần chạy thứ 2525
# Lần chạy thứ 2526
# Lần chạy thứ 2527
# Lần chạy thứ 2528
# Lần chạy thứ 2529
# Lần chạy thứ 2530
# Lần chạy thứ 2531
# Lần chạy thứ 2532
# Lần chạy thứ 2533
# Lần chạy thứ 2534
# Lần chạy thứ 2535
# Lần chạy thứ 2536
# Lần chạy thứ 2537
# Lần chạy thứ 2538
# Lần chạy thứ 2539
# Lần chạy thứ 2540
# Lần chạy thứ 2541
# Lần chạy thứ 2542
# Lần chạy thứ 2543
# Lần chạy thứ 2544
# Lần chạy thứ 2545
# Lần chạy thứ 2546
# Lần chạy thứ 2547
# Lần chạy thứ 2548
# Lần chạy thứ 2549
# Lần chạy thứ 2550
# Lần chạy thứ 2551
# Lần chạy thứ 2552
# Lần chạy thứ 2553
# Lần chạy thứ 2554
# Lần chạy thứ 2555
# Lần chạy thứ 2556
# Lần chạy thứ 2557
# Lần chạy thứ 2558
# Lần chạy thứ 2559
# Lần chạy thứ 2560
# Lần chạy thứ 2561
# Lần chạy thứ 2562
# Lần chạy thứ 2563
# Lần chạy thứ 2564
# Lần chạy thứ 2565
# Lần chạy thứ 2566
# Lần chạy thứ 2567
# Lần chạy thứ 2568
# Lần chạy thứ 2569
# Lần chạy thứ 2570
# Lần chạy thứ 2571
# Lần chạy thứ 2572
# Lần chạy thứ 2573
# Lần chạy thứ 2574
# Lần chạy thứ 2575
# Lần chạy thứ 2576
# Lần chạy thứ 2577
# Lần chạy thứ 2578
# Lần chạy thứ 2579
# Lần chạy thứ 2580
# Lần chạy thứ 2581
# Lần chạy thứ 2582
# Lần chạy thứ 2583
# Lần chạy thứ 2584
# Lần chạy thứ 2585
# Lần chạy thứ 2586
# Lần chạy thứ 2587
# Lần chạy thứ 2588
# Lần chạy thứ 2589
# Lần chạy thứ 2590
# Lần chạy thứ 2591
# Lần chạy thứ 2592
# Lần chạy thứ 2593
# Lần chạy thứ 2594
# Lần chạy thứ 2595
# Lần chạy thứ 2596
# Lần chạy thứ 2597
# Lần chạy thứ 2598
# Lần chạy thứ 2599
# Lần chạy thứ 2600
# Lần chạy thứ 2601
# Lần chạy thứ 2602
# Lần chạy thứ 2603
# Lần chạy thứ 2604
# Lần chạy thứ 2605
# Lần chạy thứ 2606
# Lần chạy thứ 2607
# Lần chạy thứ 2608
# Lần chạy thứ 2609
# Lần chạy thứ 2610
# Lần chạy thứ 2611
# Lần chạy thứ 2612
# Lần chạy thứ 2613
# Lần chạy thứ 2614
# Lần chạy thứ 2615
# Lần chạy thứ 2616
# Lần chạy thứ 2617
# Lần chạy thứ 2618
# Lần chạy thứ 2619
# Lần chạy thứ 2620
# Lần chạy thứ 2621
# Lần chạy thứ 2622
# Lần chạy thứ 2623
# Lần chạy thứ 2624
# Lần chạy thứ 2625
# Lần chạy thứ 2626
# Lần chạy thứ 2627
# Lần chạy thứ 2628
# Lần chạy thứ 2629
# Lần chạy thứ 2630
# Lần chạy thứ 2631
# Lần chạy thứ 2632
# Lần chạy thứ 2633
# Lần chạy thứ 2634
# Lần chạy thứ 2635
# Lần chạy thứ 2636
# Lần chạy thứ 2637
# Lần chạy thứ 2638
# Lần chạy thứ 2639
# Lần chạy thứ 2640
# Lần chạy thứ 2641
# Lần chạy thứ 2642
# Lần chạy thứ 2643
# Lần chạy thứ 2644
# Lần chạy thứ 2645
# Lần chạy thứ 2646
# Lần chạy thứ 2647
# Lần chạy thứ 2648
# Lần chạy thứ 2649
# Lần chạy thứ 2650
# Lần chạy thứ 2651
# Lần chạy thứ 2652
# Lần chạy thứ 2653
# Lần chạy thứ 2654
# Lần chạy thứ 2655
# Lần chạy thứ 2656
# Lần chạy thứ 2657
# Lần chạy thứ 2658
# Lần chạy thứ 2659
# Lần chạy thứ 2660
# Lần chạy thứ 2661
# Lần chạy thứ 2662
# Lần chạy thứ 2663
# Lần chạy thứ 2664
# Lần chạy thứ 2665
# Lần chạy thứ 2666
# Lần chạy thứ 2667
# Lần chạy thứ 2668
# Lần chạy thứ 2669
# Lần chạy thứ 2670
# Lần chạy thứ 2671
# Lần chạy thứ 2672
# Lần chạy thứ 2673
# Lần chạy thứ 2674
# Lần chạy thứ 2675
# Lần chạy thứ 2676
# Lần chạy thứ 2677
# Lần chạy thứ 2678
# Lần chạy thứ 2679
# Lần chạy thứ 2680
# Lần chạy thứ 2681
# Lần chạy thứ 2682
# Lần chạy thứ 2683
# Lần chạy thứ 2684
# Lần chạy thứ 2685
# Lần chạy thứ 2686
# Lần chạy thứ 2687
# Lần chạy thứ 2688
# Lần chạy thứ 2689
# Lần chạy thứ 2690
# Lần chạy thứ 2691
# Lần chạy thứ 2692
# Lần chạy thứ 2693
# Lần chạy thứ 2694
# Lần chạy thứ 2695
# Lần chạy thứ 2696
# Lần chạy thứ 2697
# Lần chạy thứ 2698
# Lần chạy thứ 2699
# Lần chạy thứ 2700
# Lần chạy thứ 2701
# Lần chạy thứ 2702
# Lần chạy thứ 2703
# Lần chạy thứ 2704
# Lần chạy thứ 2705
# Lần chạy thứ 2706
# Lần chạy thứ 2707
# Lần chạy thứ 2708
# Lần chạy thứ 2709
# Lần chạy thứ 2710
# Lần chạy thứ 2711
# Lần chạy thứ 2712
# Lần chạy thứ 2713
# Lần chạy thứ 2714
# Lần chạy thứ 2715
# Lần chạy thứ 2716
# Lần chạy thứ 2717
# Lần chạy thứ 2718
# Lần chạy thứ 2719
# Lần chạy thứ 2720
# Lần chạy thứ 2721
# Lần chạy thứ 2722
# Lần chạy thứ 2723
# Lần chạy thứ 2724
# Lần chạy thứ 2725
# Lần chạy thứ 2726
# Lần chạy thứ 2727
# Lần chạy thứ 2728
# ...
# Lần chạy thứ 46648
# Lần chạy thứ 46649
# Lần chạy thứ 46650
# Lần chạy thứ 46651
# Lần chạy thứ 46652
# Lần chạy thứ 46653
# Lần chạy thứ 46654
# Lần chạy thứ 46655
# Lần chạy thứ 46656
# Lần chạy thứ 46657
# Lần chạy thứ 46658
# Lần chạy thứ 46659
# Lần chạy thứ 46660
# Lần chạy thứ 46661
# Lần chạy thứ 46662
# Lần chạy thứ 46663
# Lần chạy thứ 46664
# Lần chạy thứ 46665
# Lần chạy thứ 46666
# Lần chạy thứ 46667
# Lần chạy thứ 46668
# Lần chạy thứ 46669
# Lần chạy thứ 46670
# Lần chạy thứ 46671
# Lần chạy thứ 46672
# Lần chạy thứ 46673
# Lần chạy thứ 46674
# Lần chạy thứ 46675
# Lần chạy thứ 46676
# Lần chạy thứ 46677
# Lần chạy thứ 46678
# Lần chạy thứ 46679
# Lần chạy thứ 46680
# Lần chạy thứ 46681
# Lần chạy thứ 46682
# Lần chạy thứ 46683
# Lần chạy thứ 46684
# Lần chạy thứ 46685
# Lần chạy thứ 46686
# Lần chạy thứ 46687
# Lần chạy thứ 46688
# Lần chạy thứ 46689
# Lần chạy thứ 46690
# Lần chạy thứ 46691
# Lần chạy thứ 46692
# Lần chạy thứ 46693
# Lần chạy thứ 46694
# Lần chạy thứ 46695
# Lần chạy thứ 46696
# Lần chạy thứ 46697
# Lần chạy thứ 46698
# Lần chạy thứ 46699
# Lần chạy thứ 46700
# Lần chạy thứ 46701
# Lần chạy thứ 46702
# Lần chạy thứ 46703
# Lần chạy thứ 46704
# Lần chạy thứ 46705
# Lần chạy thứ 46706
# Lần chạy thứ 46707
# Lần chạy thứ 46708
# Lần chạy thứ 46709
# Lần chạy thứ 46710
# Lần chạy thứ 46711
# Lần chạy thứ 46712
# Lần chạy thứ 46713
# Lần chạy thứ 46714
# Lần chạy thứ 46715
# Lần chạy thứ 46716
# Lần chạy thứ 46717
# Lần chạy thứ 46718
# Lần chạy thứ 46719
# Lần chạy thứ 46720
# Lần chạy thứ 46721
# Lần chạy thứ 46722
# Lần chạy thứ 46723
# Lần chạy thứ 46724
# Lần chạy thứ 46725
# Lần chạy thứ 46726
# Lần chạy thứ 46727
# Lần chạy thứ 46728
# Lần chạy thứ 46729
# Lần chạy thứ 46730
# Lần chạy thứ 46731
# Lần chạy thứ 46732
# Lần chạy thứ 46733
# Lần chạy thứ 46734
# Lần chạy thứ 46735
# Lần chạy thứ 46736
# Lần chạy thứ 46737
# Lần chạy thứ 46738
# Lần chạy thứ 46739
# Lần chạy thứ 46740
# Lần chạy thứ 46741
# Lần chạy thứ 46742
# Lần chạy thứ 46743
# Lần chạy thứ 46744
# Lần chạy thứ 46745
# Lần chạy thứ 46746
# Lần chạy thứ 46747
# Lần chạy thứ 46748
# Lần chạy thứ 46749
# Lần chạy thứ 46750
# Lần chạy thứ 46751
# Lần chạy thứ 46752
# Lần chạy thứ 46753
# Lần chạy thứ 46754
# Lần chạy thứ 46755
# Lần chạy thứ 46756
# Lần chạy thứ 46757
# Lần chạy thứ 46758
# Lần chạy thứ 46759
# Lần chạy thứ 46760
# Lần chạy thứ 46761
# Lần chạy thứ 46762
# Lần chạy thứ 46763
# Lần chạy thứ 46764
# Lần chạy thứ 46765
# Lần chạy thứ 46766
# Lần chạy thứ 46767
# Lần chạy thứ 46768
# Lần chạy thứ 46769
# Lần chạy thứ 46770
# Lần chạy thứ 46771
# Lần chạy thứ 46772
# Lần chạy thứ 46773
# Lần chạy thứ 46774
# Lần chạy thứ 46775
# Lần chạy thứ 46776
# Lần chạy thứ 46777
# Lần chạy thứ 46778
# Lần chạy thứ 46779
# Lần chạy thứ 46780
# Lần chạy thứ 46781
# Lần chạy thứ 46782
# Lần chạy thứ 46783
# Lần chạy thứ 46784
# Lần chạy thứ 46785
# Lần chạy thứ 46786
# Lần chạy thứ 46787
# Lần chạy thứ 46788
# Lần chạy thứ 46789
# Lần chạy thứ 46790
# Lần chạy thứ 46791
# Lần chạy thứ 46792
# Lần chạy thứ 46793
# Lần chạy thứ 46794
# Lần chạy thứ 46795
# Lần chạy thứ 46796
# Lần chạy thứ 46797
# Lần chạy thứ 46798
# Lần chạy thứ 46799
# Lần chạy thứ 46800
# Lần chạy thứ 46801
# Lần chạy thứ 46802
# Lần chạy thứ 46803
# Lần chạy thứ 46804
# Lần chạy thứ 46805
# Lần chạy thứ 46806
# Lần chạy thứ 46807
# Lần chạy thứ 46808
# Lần chạy thứ 46809
# Lần chạy thứ 46810
# Lần chạy thứ 46811
# Lần chạy thứ 46812
# Lần chạy thứ 46813
# Lần chạy thứ 46814
# Lần chạy thứ 46815
# Lần chạy thứ 46816
# Lần chạy thứ 46817
# Lần chạy thứ 46818
# Lần chạy thứ 46819
# Lần chạy thứ 46820
# Lần chạy thứ 46821
# Lần chạy thứ 46822
# Lần chạy thứ 46823
# Lần chạy thứ 46824
# Lần chạy thứ 46825
# Lần chạy thứ 46826
# Lần chạy thứ 46827
# Lần chạy thứ 46828
# Lần chạy thứ 46829
# Lần chạy thứ 46830
# Lần chạy thứ 46831
# Lần chạy thứ 46832
# Lần chạy thứ 46833
# Lần chạy thứ 46834
# Lần chạy thứ 46835
# Lần chạy thứ 46836
# Lần chạy thứ 46837
# Lần chạy thứ 46838
# Lần chạy thứ 46839
# Lần chạy thứ 46840
# Lần chạy thứ 46841
# Lần chạy thứ 46842
# Lần chạy thứ 46843
# Lần chạy thứ 46844
# Lần chạy thứ 46845
# Lần chạy thứ 46846
# Lần chạy thứ 46847
# Lần chạy thứ 46848
# Lần chạy thứ 46849
# Lần chạy thứ 46850
# Lần chạy thứ 46851
# Lần chạy thứ 46852
# Lần chạy thứ 46853
# Lần chạy thứ 46854
# Lần chạy thứ 46855
# Lần chạy thứ 46856
# Lần chạy thứ 46857
# Lần chạy thứ 46858
# Lần chạy thứ 46859
# Lần chạy thứ 46860
# Lần chạy thứ 46861
# Lần chạy thứ 46862
# Lần chạy thứ 46863
# Lần chạy thứ 46864
# Lần chạy thứ 46865
# Lần chạy thứ 46866
# Lần chạy thứ 46867
# Lần chạy thứ 46868
# Lần chạy thứ 46869
# Lần chạy thứ 46870
# Lần chạy thứ 46871
# Lần chạy thứ 46872
# Lần chạy thứ 46873
# Lần chạy thứ 46874
# Lần chạy thứ 46875
# Lần chạy thứ 46876
# Lần chạy thứ 46877
# Lần chạy thứ 46878
# Lần chạy thứ 46879
# Lần chạy thứ 46880
# Lần chạy thứ 46881
# Lần chạy thứ 46882
# Lần chạy thứ 46883
# Lần chạy thứ 46884
# Lần chạy thứ 46885
# Lần chạy thứ 46886
# Lần chạy thứ 46887
# Lần chạy thứ 46888
# Lần chạy thứ 46889
# Lần chạy thứ 46890
# Lần chạy thứ 46891
# Lần chạy thứ 46892
# Lần chạy thứ 46893
# Lần chạy thứ 46894
# Lần chạy thứ 46895
# Lần chạy thứ 46896
# Lần chạy thứ 46897
# Lần chạy thứ 46898
# Lần chạy thứ 46899
# Lần chạy thứ 46900
# Lần chạy thứ 46901
# Lần chạy thứ 46902
# Lần chạy thứ 46903
# Lần chạy thứ 46904
# Lần chạy thứ 46905
# Lần chạy thứ 46906
# Lần chạy thứ 46907
# Lần chạy thứ 46908
# Lần chạy thứ 46909
# Lần chạy thứ 46910
# Lần chạy thứ 46911
# Lần chạy thứ 46912
# Lần chạy thứ 46913
# Lần chạy thứ 46914
# Lần chạy thứ 46915
# Lần chạy thứ 46916
# Lần chạy thứ 46917
# Lần chạy thứ 46918
# Lần chạy thứ 46919
# Lần chạy thứ 46920
# Lần chạy thứ 46921
# Lần chạy thứ 46922
# Lần chạy thứ 46923
# Lần chạy thứ 46924
# Lần chạy thứ 46925
# Lần chạy thứ 46926
# Lần chạy thứ 46927
# Lần chạy thứ 46928
# Lần chạy thứ 46929
# Lần chạy thứ 46930
# Lần chạy thứ 46931
# Lần chạy thứ 46932
# Lần chạy thứ 46933
# Lần chạy thứ 46934
# Lần chạy thứ 46935
# Lần chạy thứ 46936
# Lần chạy thứ 46937
# Lần chạy thứ 46938
# Lần chạy thứ 46939
# Lần chạy thứ 46940
# Lần chạy thứ 46941
# Lần chạy thứ 46942
# Lần chạy thứ 46943
# Lần chạy thứ 46944
# Lần chạy thứ 46945
# Lần chạy thứ 46946
# Lần chạy thứ 46947
# Lần chạy thứ 46948
# Lần chạy thứ 46949
# Lần chạy thứ 46950
# Lần chạy thứ 46951
# Lần chạy thứ 46952
# Lần chạy thứ 46953
# Lần chạy thứ 46954
# Lần chạy thứ 46955
# Lần chạy thứ 46956
# Lần chạy thứ 46957
# Lần chạy thứ 46958
# Lần chạy thứ 46959
# Lần chạy thứ 46960
# Lần chạy thứ 46961
# Lần chạy thứ 46962
# Lần chạy thứ 46963
# Lần chạy thứ 46964
# Lần chạy thứ 46965
# Lần chạy thứ 46966
# Lần chạy thứ 46967
# Lần chạy thứ 46968
# Lần chạy thứ 46969
# Lần chạy thứ 46970
# Lần chạy thứ 46971
# Lần chạy thứ 46972
# Lần chạy thứ 46973
# Lần chạy thứ 46974
# Lần chạy thứ 46975
# Lần chạy thứ 46976
# Lần chạy thứ 46977
# Lần chạy thứ 46978
# Lần chạy thứ 46979
# Lần chạy thứ 46980
# Lần chạy thứ 46981
# Lần chạy thứ 46982
# Lần chạy thứ 46983
# Lần chạy thứ 46984
# Lần chạy thứ 46985
# Lần chạy thứ 46986
# Lần chạy thứ 46987
# Lần chạy thứ 46988
# Lần chạy thứ 46989
# Lần chạy thứ 46990
# Lần chạy thứ 46991
# Lần chạy thứ 46992
# Lần chạy thứ 46993
# Lần chạy thứ 46994
# Lần chạy thứ 46995
# Lần chạy thứ 46996
# Lần chạy thứ 46997
# Lần chạy thứ 46998
# Lần chạy thứ 46999
# Lần chạy thứ 47000
# Lần chạy thứ 47001
# Lần chạy thứ 47002
# Lần chạy thứ 47003
# Lần chạy thứ 47004
# Lần chạy thứ 47005
# Lần chạy thứ 47006
# Lần chạy thứ 47007
# Lần chạy thứ 47008
# Lần chạy thứ 47009
# Lần chạy thứ 47010
# Lần chạy thứ 47011
# Lần chạy thứ 47012
# Lần chạy thứ 47013
# Lần chạy thứ 47014
# Lần chạy thứ 47015
# Lần chạy thứ 47016
# Lần chạy thứ 47017
# Lần chạy thứ 47018
# Lần chạy thứ 47019
# Lần chạy thứ 47020
# Lần chạy thứ 47021
# Lần chạy thứ 47022
# Lần chạy thứ 47023
# Lần chạy thứ 47024
# Lần chạy thứ 47025
# Lần chạy thứ 47026
# Lần chạy thứ 47027
# Lần chạy thứ 47028
# Lần chạy thứ 47029
# Lần chạy thứ 47030
# Lần chạy thứ 47031
# Lần chạy thứ 47032
# Lần chạy thứ 47033
# Lần chạy thứ 47034
# Lần chạy thứ 47035
# Lần chạy thứ 47036
# Lần chạy thứ 47037
# Lần chạy thứ 47038
# Lần chạy thứ 47039
# Lần chạy thứ 47040
# Lần chạy thứ 47041
# Lần chạy thứ 47042
# Lần chạy thứ 47043
# Lần chạy thứ 47044
# Lần chạy thứ 47045
# Lần chạy thứ 47046
# Lần chạy thứ 47047
# Lần chạy thứ 47048
# Lần chạy thứ 47049
# Lần chạy thứ 47050
# Lần chạy thứ 47051
# Lần chạy thứ 47052
# Lần chạy thứ 47053
# Lần chạy thứ 47054
# Lần chạy thứ 47055
# Lần chạy thứ 47056
# Lần chạy thứ 47057
# Lần chạy thứ 47058
# Lần chạy thứ 47059
# Lần chạy thứ 47060
# Lần chạy thứ 47061
# Lần chạy thứ 47062
# Lần chạy thứ 47063
# Lần chạy thứ 47064
# Lần chạy thứ 47065
# Lần chạy thứ 47066
# Lần chạy thứ 47067
# Lần chạy thứ 47068
# Lần chạy thứ 47069
# Lần chạy thứ 47070
# Lần chạy thứ 47071
# Lần chạy thứ 47072
# Lần chạy thứ 47073
# Lần chạy thứ 47074
# Lần chạy thứ 47075
# Lần chạy thứ 47076
# Lần chạy thứ 47077
# Lần chạy thứ 47078
# Lần chạy thứ 47079
# Lần chạy thứ 47080
# Lần chạy thứ 47081
# Lần chạy thứ 47082
# Lần chạy thứ 47083
# Lần chạy thứ 47084
# Lần chạy thứ 47085
# Lần chạy thứ 47086
# Lần chạy thứ 47087
# Lần chạy thứ 47088
# Lần chạy thứ 47089
# Lần chạy thứ 47090
# Lần chạy thứ 47091
# Lần chạy thứ 47092
# Lần chạy thứ 47093
# Lần chạy thứ 47094
# Lần chạy thứ 47095
# Lần chạy thứ 47096
# Lần chạy thứ 47097
# Lần chạy thứ 47098
# Lần chạy thứ 47099
# Lần chạy thứ 47100
# Lần chạy thứ 47101
# Lần chạy thứ 47102
# Lần chạy thứ 47103
# Lần chạy thứ 47104
# Lần chạy thứ 47105
# Lần chạy thứ 47106
# Lần chạy thứ 47107
# Lần chạy thứ 47108
# Lần chạy thứ 47109
# Lần chạy thứ 47110
# Lần chạy thứ 47111
# Lần chạy thứ 47112
# Lần chạy thứ 47113
# Lần chạy thứ 47114
# Lần chạy thứ 47115
# Lần chạy thứ 47116
# Lần chạy thứ 47117
# Lần chạy thứ 47118
# Lần chạy thứ 47119
# Lần chạy thứ 47120
# Lần chạy thứ 47121
# Lần chạy thứ 47122
# Lần chạy thứ 47123
# Lần chạy thứ 47124
# Lần chạy thứ 47125
# Lần chạy thứ 47126
# Lần chạy thứ 47127
# Lần chạy thứ 47128
# Lần chạy thứ 47129
# Lần chạy thứ 47130
# Lần chạy thứ 47131
# Lần chạy thứ 47132
# Lần chạy thứ 47133
# Lần chạy thứ 47134
# Lần chạy thứ 47135
# Lần chạy thứ 47136
# Lần chạy thứ 47137
# Lần chạy thứ 47138
# Lần chạy thứ 47139
# Lần chạy thứ 47140
# Lần chạy thứ 47141
# Lần chạy thứ 47142
# Lần chạy thứ 47143
# Lần chạy thứ 47144
# Lần chạy thứ 47145
# Lần chạy thứ 47146
# Lần chạy thứ 47147
# Lần chạy thứ 47148
# Lần chạy thứ 47149
# Lần chạy thứ 47150
# Lần chạy thứ 47151
# Lần chạy thứ 47152
# Lần chạy thứ 47153
# Lần chạy thứ 47154
# Lần chạy thứ 47155
# Lần chạy thứ 47156
# Lần chạy thứ 47157
# Lần chạy thứ 47158
# Lần chạy thứ 47159
# Lần chạy thứ 47160
# Lần chạy thứ 47161
# Lần chạy thứ 47162
# Lần chạy thứ 47163
# Lần chạy thứ 47164
# Lần chạy thứ 47165
# Lần chạy thứ 47166
# Lần chạy thứ 47167
# Lần chạy thứ 47168
# Lần chạy thứ 47169
# Lần chạy thứ 47170
# Lần chạy thứ 47171
# Lần chạy thứ 47172
# Lần chạy thứ 47173
# Lần chạy thứ 47174
# Lần chạy thứ 47175
# Lần chạy thứ 47176
# Lần chạy thứ 47177
# Lần chạy thứ 47178
# Lần chạy thứ 47179
# Lần chạy thứ 47180
# Lần chạy thứ 47181
# Lần chạy thứ 47182
# Lần chạy thứ 47183
# Lần chạy thứ 47184
# Lần chạy thứ 47185
# Lần chạy thứ 47186
# Lần chạy thứ 47187
# Lần chạy thứ 47188
# Lần chạy thứ 47189
# Lần chạy thứ 47190
# Lần chạy thứ 47191
# Lần chạy thứ 47192
# Lần chạy thứ 47193
# Lần chạy thứ 47194
# Lần chạy thứ 47195
# Lần chạy thứ 47196
# Lần chạy thứ 47197
# Lần chạy thứ 47198
# Lần chạy thứ 47199
# Lần chạy thứ 47200
# Lần chạy thứ 47201
# Lần chạy thứ 47202
# Lần chạy thứ 47203
# Lần chạy thứ 47204
# Lần chạy thứ 47205
# Lần chạy thứ 47206
# Lần chạy thứ 47207
# Lần chạy thứ 47208
# Lần chạy thứ 47209
# Lần chạy thứ 47210
# Lần chạy thứ 47211
# Lần chạy thứ 47212
# Lần chạy thứ 47213
# Lần chạy thứ 47214
# Lần chạy thứ 47215
# Lần chạy thứ 47216
# Lần chạy thứ 47217
# Lần chạy thứ 47218
# Lần chạy thứ 47219
# Lần chạy thứ 47220
# Lần chạy thứ 47221
# Lần chạy thứ 47222
# Lần chạy thứ 47223
# Lần chạy thứ 47224
# Lần chạy thứ 47225
# Lần chạy thứ 47226
# Lần chạy thứ 47227
# Lần chạy thứ 47228
# Lần chạy thứ 47229
# Lần chạy thứ 47230
# Lần chạy thứ 47231
# Lần chạy thứ 47232
# Lần chạy thứ 47233
# Lần chạy thứ 47234
# Lần chạy thứ 47235
# Lần chạy thứ 47236
# Lần chạy thứ 47237
# Lần chạy thứ 47238
# Lần chạy thứ 47239
# Lần chạy thứ 47240
# Lần chạy thứ 47241
# Lần chạy thứ 47242
# Lần chạy thứ 47243
# Lần chạy thứ 47244
# Lần chạy thứ 47245
# Lần chạy thứ 47246
# Lần chạy thứ 47247
# Lần chạy thứ 47248
# Lần chạy thứ 47249
# Lần chạy thứ 47250
# Lần chạy thứ 47251
# Lần chạy thứ 47252
# Lần chạy thứ 47253
# Lần chạy thứ 47254
# Lần chạy thứ 47255
# Lần chạy thứ 47256
# Lần chạy thứ 47257
# Lần chạy thứ 47258
# Lần chạy thứ 47259
# Lần chạy thứ 47260
# Lần chạy thứ 47261
# Lần chạy thứ 47262
# Lần chạy thứ 47263
# Lần chạy thứ 47264
# Lần chạy thứ 47265
# Lần chạy thứ 47266
# Lần chạy thứ 47267
# Lần chạy thứ 47268
# Lần chạy thứ 47269
# Lần chạy thứ 47270
# Lần chạy thứ 47271
# Lần chạy thứ 47272
# Lần chạy thứ 47273
# Lần chạy thứ 47274
# Lần chạy thứ 47275
# Lần chạy thứ 47276
# Lần chạy thứ 47277
# Lần chạy thứ 47278
# Lần chạy thứ 47279
# Lần chạy thứ 47280
# Lần chạy thứ 47281
# Lần chạy thứ 47282
# Lần chạy thứ 47283
# Lần chạy thứ 47284
# Lần chạy thứ 47285
# Lần chạy thứ 47286
# Lần chạy thứ 47287
# Lần chạy thứ 47288
# Lần chạy thứ 47289
# Lần chạy thứ 47290
# Lần chạy thứ 47291
# Lần chạy thứ 47292
# Lần chạy thứ 47293
# Lần chạy thứ 47294
# Lần chạy thứ 47295
# Lần chạy thứ 47296
# Lần chạy thứ 47297
# Lần chạy thứ 47298
# Lần chạy thứ 47299
# Lần chạy thứ 47300
# Lần chạy thứ 47301
# Lần chạy thứ 47302
# Lần chạy thứ 47303
# Lần chạy thứ 47304
# Lần chạy thứ 47305
# Lần chạy thứ 47306
# Lần chạy thứ 47307
# Lần chạy thứ 47308
# Lần chạy thứ 47309
# Lần chạy thứ 47310
# Lần chạy thứ 47311
# Lần chạy thứ 47312
# Lần chạy thứ 47313
# Lần chạy thứ 47314
# Lần chạy thứ 47315
# Lần chạy thứ 47316
# Lần chạy thứ 47317
# Lần chạy thứ 47318
# Lần chạy thứ 47319
# Lần chạy thứ 47320
# Lần chạy thứ 47321
# Lần chạy thứ 47322
# Lần chạy thứ 47323
# Lần chạy thứ 47324
# Lần chạy thứ 47325
# Lần chạy thứ 47326
# Lần chạy thứ 47327
# Lần chạy thứ 47328
# Lần chạy thứ 47329
# Lần chạy thứ 47330
# Lần chạy thứ 47331
# Lần chạy thứ 47332
# Lần chạy thứ 47333
# Lần chạy thứ 47334
# Lần chạy thứ 47335
# Lần chạy thứ 47336
# Lần chạy thứ 47337
# Lần chạy thứ 47338
# Lần chạy thứ 47339
# Lần chạy thứ 47340
# Lần chạy thứ 47341
# Lần chạy thứ 47342
# Lần chạy thứ 47343
# Lần chạy thứ 47344
# Lần chạy thứ 47345
# Lần chạy thứ 47346
# Lần chạy thứ 47347
# Lần chạy thứ 47348
# Lần chạy thứ 47349
# Lần chạy thứ 47350
# Lần chạy thứ 47351
# Lần chạy thứ 47352
# Lần chạy thứ 47353
# Lần chạy thứ 47354
# Lần chạy thứ 47355
# Lần chạy thứ 47356
# Lần chạy thứ 47357
# Lần chạy thứ 47358
# Lần chạy thứ 47359
# Lần chạy thứ 47360
# Lần chạy thứ 47361
# Lần chạy thứ 47362
# Lần chạy thứ 47363
# Lần chạy thứ 47364
# Lần chạy thứ 47365
# Lần chạy thứ 47366
# Lần chạy thứ 47367
# Lần chạy thứ 47368
# Lần chạy thứ 47369
# Lần chạy thứ 47370
# Lần chạy thứ 47371
# Lần chạy thứ 47372
# Lần chạy thứ 47373
# Lần chạy thứ 47374
# Lần chạy thứ 47375
# Lần chạy thứ 47376
# Lần chạy thứ 47377
# Lần chạy thứ 47378
# Lần chạy thứ 47379
# Lần chạy thứ 47380
# Lần chạy thứ 47381
# Lần chạy thứ 47382
# Lần chạy thứ 47383
# Lần chạy thứ 47384
# Lần chạy thứ 47385
# Lần chạy thứ 47386
# Lần chạy thứ 47387
# Lần chạy thứ 47388
# Lần chạy thứ 47389
# Lần chạy thứ 47390
# Lần chạy thứ 47391
# Lần chạy thứ 47392
# Lần chạy thứ 47393
# Lần chạy thứ 47394
# Lần chạy thứ 47395
# Lần chạy thứ 47396
# Lần chạy thứ 47397
# Lần chạy thứ 47398
# Lần chạy thứ 47399
# Lần chạy thứ 47400
# Lần chạy thứ 47401
# Lần chạy thứ 47402
# Lần chạy thứ 47403
# Lần chạy thứ 47404
# Lần chạy thứ 47405
# Lần chạy thứ 47406
# Lần chạy thứ 47407
# Lần chạy thứ 47408
# Lần chạy thứ 47409
# Lần chạy thứ 47410
# Lần chạy thứ 47411
# Lần chạy thứ 47412
# Lần chạy thứ 47413
# Lần chạy thứ 47414
# Lần chạy thứ 47415
# Lần chạy thứ 47416
# Lần chạy thứ 47417
# Lần chạy thứ 47418
# Lần chạy thứ 47419
# Lần chạy thứ 47420
# Lần chạy thứ 47421
# Lần chạy thứ 47422
# Lần chạy thứ 47423
# Lần chạy thứ 47424
# Lần chạy thứ 47425
# Lần chạy thứ 47426
# Lần chạy thứ 47427
# Lần chạy thứ 47428
# Lần chạy thứ 47429
# Lần chạy thứ 47430
# Lần chạy thứ 47431
# Lần chạy thứ 47432
# Lần chạy thứ 47433
# Lần chạy thứ 47434
# Lần chạy thứ 47435
# Lần chạy thứ 47436
# Lần chạy thứ 47437
# Lần chạy thứ 47438
# Lần chạy thứ 47439
# Lần chạy thứ 47440
# Lần chạy thứ 47441
# Lần chạy thứ 47442
# Lần chạy thứ 47443
# Lần chạy thứ 47444
# Lần chạy thứ 47445
# Lần chạy thứ 47446
# Lần chạy thứ 47447
# Lần chạy thứ 47448
# Lần chạy thứ 47449
# Lần chạy thứ 47450
# Lần chạy thứ 47451
# Lần chạy thứ 47452
# Lần chạy thứ 47453
# Lần chạy thứ 47454
# Lần chạy thứ 47455
# Lần chạy thứ 47456
# Lần chạy thứ 47457
# Lần chạy thứ 47458
# Lần chạy thứ 47459
# Lần chạy thứ 47460
# Lần chạy thứ 47461
# Lần chạy thứ 47462
# Lần chạy thứ 47463
# (47463, 3)
#                                                 hash
# 0  0x1d8dc0228d0ecc674c00dbc8c02dfc31e235ee1f2577...  \
# 1  0xdf3a1a30c2914b306dd8cb45b5227232daa29f809bfe...
# 2  0xc4120db5c02a21116ad9e9dabc9dafa6ef2ef6e6e4e3...
#
#                                                image label
# 0  [[73.84920756022814, 0.6367703672874825, 73.84...     1
# 1  [[129.64242202933613, 242.74217042971594, 0.00...     0
# 2  [[142.77839515318158, 31.334408490271557, 20.7...     0

# %%
image_arrays = data_df['image'].tolist()

# Tạo numpy array từ danh sách các mảng 2D
np_images = np.stack(image_arrays, axis=0)
# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(data_df['image'].values, data_df['label'].values, test_size=0.1, random_state=42)
print(type(X_train))
print(type(y_train))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# Required Libraries
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, LeakyReLU, Dropout, Flatten, Lambda, Activation, Reshape, Conv2DTranspose, Conv1DTranspose, Conv1D
# from keras.utils.vis_utils import plot_model
from keras.datasets.mnist import load_data
from keras import backend as K
from tensorflow.keras.optimizers import Adam
from numpy.random import randn, randint
from numpy import expand_dims, zeros, ones, asarray
from matplotlib import pyplot

# load the images
def load_real_samples(n_classes=10):
    # (trainX, trainy), (_, _) = load_data()
    trainX, _, trainy, _ = train_test_split(np_images, data_df['label'].values, test_size=0.2, random_state=42)

    # print(trainX.shape, trainy.shape)
    # print(type(trainX))
    # print(trainX[0])
    # print(type(trainX[0][0]))
    # print(type(trainy))
    # print(trainy[2])
    X = expand_dims(trainX, axis=-1)
    X = X.astype('float32')
    trainy = trainy.astype('uint8')
    X = (X - 127.5) / 127.5  # scale from [0,255] to [-1,1] as we will be using tanh activation.

    # Convert pandas to numpy for trainy
    # trainy = trainy.values
    # print(X[0])
    # print(type(X))
    # print(X.shape, trainy.shape)
    return [X, trainy]

data = load_real_samples()

# %%
from numpy import expand_dims, zeros, ones, asarray
from numpy.random import randn, randint

from keras.datasets.mnist import load_data
from keras.optimizers import Adam
from keras.models import Model, Sequential

from keras.layers import Input, Dense, Reshape, Flatten, Conv2D, Conv2DTranspose
from keras.layers import LeakyReLU, Dropout, Lambda, Activation

#from keras.utils import to_categorical

from matplotlib import pyplot as plt
from keras import backend as K
import numpy as np

# define the standalone generator model
def define_generator(latent_dim):

	in_lat = Input(shape=(latent_dim,))
	#Start with enough dense nodes to be reshaped and ConvTransposed to 28x28x1
	n_nodes = 256 * 6 * 6
	X = Dense(n_nodes)(in_lat)
	X = LeakyReLU(alpha=0.2)(X)
	X = Reshape((6, 6, 256))(X)

	X = Conv2DTranspose(128, (3,3), strides=(5,5), padding='same')(X) #14x14x128
	X = LeakyReLU(alpha=0.2)(X)

	X = Conv2DTranspose(64, (3,3), strides=(1,1), padding='same')(X) #14x14x64
	X = LeakyReLU(alpha=0.2)(X)
	# output
	out_layer = Conv2DTranspose(1, (3,3), strides=(1,1), activation='sigmoid',
                             padding='same')(X) #28x28x1
	# define model
	model = Model(in_lat, out_layer)
	return model

# gen_model=define_generator(100)
# print(gen_model.summary())

# define the base discriminator model for sup and unsup discriminators
#This is the base discriminator that supervised and unsupervised are going to share weights from.
#(I know that the above ssentence is bad english!!!)
def define_discriminator(in_shape=(30,30,1), n_classes=2):
    in_image = Input(shape=in_shape)
    X = Conv2D(32, (3,3), strides=(2,2), padding='same')(in_image)
    X = LeakyReLU(alpha=0.2)(X)

    X = Conv2D(64, (3,3), strides=(2,2), padding='same')(X)
    X = LeakyReLU(alpha=0.2)(X)

    X = Conv2D(128, (3,3), strides=(2,2), padding='same')(X)
    X = LeakyReLU(alpha=0.2)(X)

    X = Flatten()(X)
    X = Dropout(0.4)(X) #Consider adding more dropout layers to minimize overfitting - remember we work with limited labeled data.
    X = Dense(n_classes)(X)

    model = Model(inputs=in_image, outputs=X)

    return model

#Define the supervised discriminator.
#Multiclass classification, so we will use softmax activation.
#To avoid converting our labels to categorical, we will work with sparse categorical crossentropy loss.
def define_sup_discriminator(disc):
    model=Sequential()
    model.add(disc)
    model.add(Activation('sigmoid'))
    #Let us use sparse categorical loss so we dont have to convert our Y to categorical
    model.compile(optimizer=Adam(learning_rate=0.0001, beta_1=0.5),
                  loss="sparse_categorical_crossentropy",metrics=['accuracy'])
    return model


#Define the unsupervised discriminator
#Takes the output of the supervised, just before the softmax activation.
#Then, adds a layer with calculation of sum of exponential outputs. (defined below as custom_activation)
# Reference: https://arxiv.org/abs/1606.03498

#This custom activation layer gives a value close to 0 for smaller activations
#in the prior discriminator layer. It gives values close to 1 for large activations.
#This way it gives low activation for fake images. No need for sigmoid anymore.

# custom activation function for the unsupervised discriminator
#D(x) = Z(x) / (Z(x) + 1) where Z(x) = sum(exp(l(x))). l(x) is the output from sup discr. prior to softmax
def custom_activation(x):
    Z_x = K.sum(K.exp(x), axis=-1, keepdims=True)
    D_x = Z_x /(Z_x+1)

    return D_x

#You can also try the built in tensorflow function: tf.reduce_logsumexp(class_logits, 1)

def define_unsup_discriminator(disc):
    model=Sequential()
    model.add(disc)
    model.add(Lambda(custom_activation))
    model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0001, beta_1=0.5))
    return model


# disc=define_discriminator()
# disc_sup=define_sup_discriminator(disc)
# disc_unsup=define_unsup_discriminator(disc)
# print(disc_unsup.summary())


# define the combined generator and discriminator model, for updating the generator
def define_gan(gen_model, disc_unsup):

	disc_unsup.trainable = False # make unsup. discriminator not trainable
	gan_output = disc_unsup(gen_model.output) #Gen. output is the input to disc.
	model = Model(gen_model.input, gan_output)
	model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0001, beta_1=0.5))
	return model

# gan_model = define_gan(gen_model, disc_unsup)
# print(gan_model.summary())

#select subset of the dataset for supervised training
#Let us pick only 100 samples to be used in supervised training.
#Also, we need to ensure we pick 10 samples per class to ensure a good balance
#of data between classes.
def select_supervised_samples(dataset, n_samples=100, n_classes=2):
 	X, y = dataset
 	X_list, y_list = list(), list()
 	n_per_class = int(n_samples / n_classes) #Number of amples per class.
 	for i in range(n_classes):
         X_with_class = X[y == i] # get all images for this class
         ix = randint(0, len(X_with_class), n_per_class) # choose random images for each class
         [X_list.append(X_with_class[j]) for j in ix] # add to list
         [y_list.append(i) for j in ix]
 	return asarray(X_list), asarray(y_list) #Returns a list of 2 numpy arrays corresponding to X and Y


# Pick real samples from the dataset.
#Return both images and corresponding labels in addition to y=1 indicating that the images are real.
#Remember that we will not use the labels for unsupervised, only used for supervised.
def generate_real_samples(dataset, n_samples):

	images, labels = dataset
	ix = randint(0, images.shape[0], n_samples)
	X, labels = images[ix], labels[ix] #Select random images and corresponding labels
	y = ones((n_samples, 1)) #Label all images as 1 as these are real images. (for the discriminator training)
	return [X, labels], y

# generate latent points, to be used as inputs to the generator.
def generate_latent_points(latent_dim, n_samples):
	z_input = randn(latent_dim * n_samples)
	z_input = z_input.reshape(n_samples, latent_dim) # reshape for input to the network
	return z_input

# Generate fake images using the generator and above latent points as input to it.
#We do not care about labeles so the generator will not know anything about the labels.
def generate_fake_samples(generator, latent_dim, n_samples):

	z_input = generate_latent_points(latent_dim, n_samples)
	fake_images = generator.predict(z_input)
	# create class labels
	y = zeros((n_samples, 1)) #Label all images as 0 as these are fake images. (for the discriminator training)
	return fake_images, y

# report accuracy and save plots & the model periodically.
def summarize_performance(step, gen_model, disc_sup, latent_dim, dataset, n_samples=100):
	# Generate fake images
	X, _ = generate_fake_samples(gen_model, latent_dim, n_samples)

# 	X = (X + 1) / 2.0 # scale to [0,1] for plotting
# 	# plot images
# 	for i in range(100):
# 		plt.subplot(10, 10, 1 + i)
# 		plt.axis('off')
# 		plt.imshow(X[i, :, :, 0], cmap='gray_r')
# 	# save plot to drive
# 	filename1 = 'generated_plot_%04d.png' % (step+1)
# 	plt.savefig(filename1)
# 	plt.close()

	# evaluate the discriminator
	X, y = dataset
	_, acc = disc_sup.evaluate(X, y, verbose=0)
	print('Discriminator Accuracy: %.3f%%' % (acc * 100))
	# save the generator model
	filename2 = './Result-ML/SGAN-imagev2/Test_1/gen_model_%04d.h5' % (step+1)
	gen_model.save(filename2)
	# save the Discriminator (classifier) model
	filename3 = './Result-ML/SGAN-imagev2/Test_1/disc_sup_%04d.h5' % (step+1)
	disc_sup.save(filename3)
# 	print('>Saved: %s, %s, and %s' % (filename1, filename2, filename3))

# train the generator and discriminator
def train(gen_model, disc_unsup, disc_sup, gan_model, dataset, latent_dim, n_epochs=20, n_batch=32):

    # select supervised dataset for training.
    #Remember that we are not using all 60k images, just a subset (100 images, 10 per class. )
	X_sup, y_sup = select_supervised_samples(dataset)
	#print(X_sup.shape, y_sup.shape)

	bat_per_epo = int(dataset[0].shape[0] / n_batch)
	# iterations
	n_steps = bat_per_epo * n_epochs

	half_batch = int(n_batch / 2)
	print('n_epochs=%d, n_batch=%d, 1/2=%d, b/e=%d, steps=%d' % (n_epochs,
                                                              n_batch, half_batch,
                                                              bat_per_epo, n_steps))

    #  enumerate epochs
	for i in range(n_steps):
		# update supervised discriminator (disc_sup) on real samples.
        #Remember that we use real labels to train as this is supervised.
        #This is the discriminator we really care about at the end.
        #Also, this is a multiclass classifier, not binary. Therefore, our y values
        #will be the real class labels for MNIST. (NOT 1 or 0 indicating real or fake.)
		[Xsup_real, ysup_real], _ = generate_real_samples([X_sup, y_sup], half_batch)
		sup_loss, sup_acc = disc_sup.train_on_batch(Xsup_real, ysup_real)

		# update unsupervised discriminator (disc_unsup) - just like in our regular GAN.
        #Remember that we will not train on labels as this is unsupervised, just binary as in our regular GAN.
        #The y_real below indicates 1s telling the discriminator that these images are real.
        #do not confuse this with class labels.
        #We will discard this discriminator at the end.
		[X_real, _], y_real = generate_real_samples(dataset, half_batch) #
		d_loss_real = disc_unsup.train_on_batch(X_real, y_real)
        #Now train on fake.
		X_fake, y_fake = generate_fake_samples(gen_model, latent_dim, half_batch)
		d_loss_fake = disc_unsup.train_on_batch(X_fake, y_fake)

		# update generator (gen) - like we do in regular GAN.
        #We can discard this model at the end as our primary goal is to train a multiclass classifier (sup. disc.)
		X_gan, y_gan = generate_latent_points(latent_dim, n_batch), ones((n_batch, 1))
		gan_loss = gan_model.train_on_batch(X_gan, y_gan)

		# summarize loss on this batch
		print('>%d, c[%.3f,%.0f], d[%.3f,%.3f], g[%.3f]' % (i+1, sup_loss, sup_acc*100, d_loss_real, d_loss_fake, gan_loss))
		# evaluate the model performance periodically
		if (i+1) % (bat_per_epo * 2) == 0:
			summarize_performance(i, gen_model, disc_sup, latent_dim, dataset)

#################################################################################
# TRAIN
#################################

latent_dim = 100

# create the discriminator models
disc=define_discriminator() #Bare discriminator model...
disc_sup=define_sup_discriminator(disc) #Supervised discriminator model
disc_unsup=define_unsup_discriminator(disc) #Unsupervised discriminator model.

gen_model = define_generator(latent_dim) #Generator
gan_model = define_gan(gen_model, disc_unsup) #GAN
dataset = load_real_samples() #Define the dataset by loading real samples. (This will be a list of 2 numpy arrays, X and y)

# train the model
# NOTE: 1 epoch = 600 steps in this example.
train(gen_model, disc_unsup, disc_sup, gan_model, dataset, latent_dim, n_epochs=8000, n_batch=32)
# Out:
# n_epochs=8000, n_batch=32, 1/2=16, b/e=1186, steps=9488000
# 1/1 [==============================] - 0s 208ms/step
# >1, c[0.674,69], d[0.384,1.093], g[0.412]
# 1/1 [==============================] - 0s 51ms/step
# >2, c[0.699,56], d[0.367,1.083], g[0.419]
# 1/1 [==============================] - 0s 43ms/step
# >3, c[0.710,44], d[0.349,1.071], g[0.427]
# 1/1 [==============================] - 0s 40ms/step
# >4, c[0.687,50], d[0.338,1.053], g[0.431]
# 1/1 [==============================] - 0s 45ms/step
# >5, c[0.679,62], d[0.317,1.046], g[0.438]
# 1/1 [==============================] - 0s 38ms/step
# >6, c[0.679,50], d[0.302,1.024], g[0.449]
# 1/1 [==============================] - 0s 37ms/step
# >7, c[0.741,31], d[0.288,1.015], g[0.458]
# 1/1 [==============================] - 0s 42ms/step
# >8, c[0.693,56], d[0.279,1.001], g[0.468]
# 1/1 [==============================] - 0s 39ms/step
# >9, c[0.688,50], d[0.261,0.981], g[0.480]
# 1/1 [==============================] - 0s 43ms/step
# >10, c[0.684,50], d[0.246,0.959], g[0.490]
# 1/1 [==============================] - 0s 39ms/step
# >11, c[0.678,62], d[0.220,0.941], g[0.507]
# 1/1 [==============================] - 0s 81ms/step
# >12, c[0.733,31], d[0.211,0.923], g[0.522]
# 1/1 [==============================] - 0s 42ms/step
# >13, c[0.708,62], d[0.193,0.891], g[0.539]
# 1/1 [==============================] - 0s 38ms/step
# >14, c[0.717,38], d[0.178,0.867], g[0.564]
# 1/1 [==============================] - 0s 39ms/step
# >15, c[0.705,50], d[0.167,0.848], g[0.578]
# 1/1 [==============================] - 0s 42ms/step
# >16, c[0.715,50], d[0.146,0.820], g[0.601]
# 1/1 [==============================] - 0s 39ms/step
# >17, c[0.695,50], d[0.132,0.783], g[0.628]
# 1/1 [==============================] - 0s 38ms/step
# >18, c[0.700,50], d[0.126,0.759], g[0.651]
# 1/1 [==============================] - 0s 37ms/step
# >19, c[0.692,56], d[0.111,0.728], g[0.688]
# 1/1 [==============================] - 0s 32ms/step
# >20, c[0.726,44], d[0.098,0.692], g[0.729]
# 1/1 [==============================] - 0s 35ms/step
# >21, c[0.695,56], d[0.086,0.659], g[0.756]
# 1/1 [==============================] - 0s 39ms/step
# >22, c[0.672,69], d[0.079,0.635], g[0.786]
# 1/1 [==============================] - 0s 36ms/step
# >23, c[0.686,50], d[0.069,0.601], g[0.832]
# 1/1 [==============================] - 0s 36ms/step
# >24, c[0.690,56], d[0.058,0.575], g[0.874]
# 1/1 [==============================] - 0s 35ms/step
# >25, c[0.689,56], d[0.049,0.555], g[0.911]
# 1/1 [==============================] - 0s 37ms/step
# >26, c[0.694,50], d[0.045,0.520], g[0.951]
# 1/1 [==============================] - 0s 34ms/step
# >27, c[0.682,62], d[0.037,0.502], g[0.981]
# 1/1 [==============================] - 0s 34ms/step
# >28, c[0.738,38], d[0.031,0.483], g[0.985]
# 1/1 [==============================] - 0s 35ms/step
# >29, c[0.698,44], d[0.029,0.471], g[1.021]
# 1/1 [==============================] - 0s 42ms/step
# >30, c[0.721,44], d[0.026,0.453], g[1.047]
# 1/1 [==============================] - 0s 39ms/step
# >31, c[0.712,62], d[0.024,0.463], g[1.054]
# 1/1 [==============================] - 0s 36ms/step
# >32, c[0.639,62], d[0.019,0.445], g[1.039]
# 1/1 [==============================] - 0s 46ms/step
# >33, c[0.784,62], d[0.017,0.456], g[1.051]
# 1/1 [==============================] - 0s 36ms/step
# >34, c[0.535,75], d[0.016,0.446], g[1.033]
# 1/1 [==============================] - 0s 37ms/step
# >35, c[0.908,38], d[0.015,0.480], g[1.026]
# 1/1 [==============================] - 0s 35ms/step
# >36, c[0.788,50], d[0.014,0.481], g[1.029]
# 1/1 [==============================] - 0s 35ms/step
# >37, c[0.801,50], d[0.013,0.486], g[0.996]
# 1/1 [==============================] - 0s 36ms/step
# >38, c[0.705,56], d[0.012,0.473], g[0.997]
# 1/1 [==============================] - 0s 35ms/step
# >39, c[0.664,50], d[0.010,0.494], g[0.992]
# 1/1 [==============================] - 0s 34ms/step
# >40, c[0.612,81], d[0.010,0.498], g[0.975]
# 1/1 [==============================] - 0s 34ms/step
# >41, c[0.746,56], d[0.009,0.489], g[0.999]
# 1/1 [==============================] - 0s 33ms/step
# >42, c[0.694,62], d[0.009,0.487], g[0.993]
# 1/1 [==============================] - 0s 33ms/step
# >43, c[0.708,50], d[0.008,0.489], g[0.970]
# 1/1 [==============================] - 0s 35ms/step
# >44, c[0.740,38], d[0.008,0.483], g[1.025]
# 1/1 [==============================] - 0s 33ms/step
# >45, c[0.688,56], d[0.007,0.487], g[0.975]
# 1/1 [==============================] - 0s 35ms/step
# >46, c[0.746,50], d[0.007,0.470], g[0.982]
# 1/1 [==============================] - 0s 35ms/step
# >47, c[0.704,62], d[0.006,0.481], g[1.020]
# 1/1 [==============================] - 0s 34ms/step
# >48, c[0.800,38], d[0.007,0.460], g[1.039]
# 1/1 [==============================] - 0s 37ms/step
# >49, c[0.763,50], d[0.005,0.453], g[1.041]
# 1/1 [==============================] - 0s 34ms/step
# >50, c[0.730,62], d[0.005,0.423], g[1.067]
# 1/1 [==============================] - 0s 34ms/step
# >51, c[0.797,38], d[0.005,0.428], g[1.119]
# 1/1 [==============================] - 0s 46ms/step
# >52, c[0.745,38], d[0.005,0.414], g[1.142]
# 1/1 [==============================] - 0s 45ms/step
# >53, c[0.793,50], d[0.004,0.392], g[1.151]
# 1/1 [==============================] - 0s 61ms/step
# >54, c[0.720,56], d[0.004,0.399], g[1.161]
# 1/1 [==============================] - 0s 48ms/step
# >55, c[0.667,56], d[0.004,0.360], g[1.208]
# 1/1 [==============================] - 0s 51ms/step
# >56, c[0.684,62], d[0.003,0.353], g[1.235]
# 1/1 [==============================] - 0s 46ms/step
# >57, c[0.846,31], d[0.004,0.336], g[1.285]
# 1/1 [==============================] - 0s 38ms/step
# >58, c[0.664,62], d[0.003,0.321], g[1.297]
# 1/1 [==============================] - 0s 50ms/step
# >59, c[0.656,38], d[0.003,0.307], g[1.369]
# 1/1 [==============================] - 0s 48ms/step
# >60, c[0.889,25], d[0.003,0.291], g[1.425]
# 1/1 [==============================] - 0s 39ms/step
# >61, c[0.745,56], d[0.003,0.269], g[1.453]
# 1/1 [==============================] - 0s 47ms/step
# >62, c[0.775,38], d[0.003,0.257], g[1.507]
# 1/1 [==============================] - 0s 36ms/step
# >63, c[0.725,44], d[0.003,0.260], g[1.554]
# 1/1 [==============================] - 0s 44ms/step
# >64, c[0.736,38], d[0.003,0.229], g[1.592]
# 1/1 [==============================] - 0s 43ms/step
# >65, c[0.834,31], d[0.003,0.218], g[1.648]
# 1/1 [==============================] - 0s 34ms/step
# >66, c[0.720,56], d[0.003,0.216], g[1.717]
# 1/1 [==============================] - 0s 36ms/step
# >67, c[0.648,69], d[0.002,0.199], g[1.779]
# 1/1 [==============================] - 0s 39ms/step
# >68, c[0.623,75], d[0.002,0.178], g[1.817]
# 1/1 [==============================] - 0s 38ms/step
# >69, c[0.742,50], d[0.002,0.180], g[1.848]
# 1/1 [==============================] - 0s 32ms/step
# >70, c[0.820,25], d[0.002,0.167], g[1.935]
# 1/1 [==============================] - 0s 34ms/step
# >71, c[0.650,69], d[0.002,0.160], g[1.996]
# 1/1 [==============================] - 0s 45ms/step
# >72, c[0.748,44], d[0.002,0.149], g[2.052]
# 1/1 [==============================] - 0s 36ms/step
# >73, c[0.676,69], d[0.002,0.140], g[2.086]
# 1/1 [==============================] - 0s 34ms/step
# >74, c[0.689,62], d[0.002,0.131], g[2.160]
# 1/1 [==============================] - 0s 39ms/step
# >75, c[0.670,56], d[0.002,0.125], g[2.259]
# 1/1 [==============================] - 0s 33ms/step
# >76, c[0.858,50], d[0.002,0.120], g[2.301]
# 1/1 [==============================] - 0s 38ms/step
# >77, c[0.756,56], d[0.002,0.106], g[2.330]
# 1/1 [==============================] - 0s 35ms/step
# >78, c[0.720,50], d[0.002,0.099], g[2.401]
# 1/1 [==============================] - 0s 36ms/step
# >79, c[0.670,56], d[0.002,0.093], g[2.434]
# 1/1 [==============================] - 0s 35ms/step
# >80, c[0.744,50], d[0.002,0.091], g[2.519]
# 1/1 [==============================] - 0s 38ms/step
# >81, c[0.682,56], d[0.002,0.082], g[2.569]
# 1/1 [==============================] - 0s 34ms/step
# >82, c[0.783,31], d[0.002,0.076], g[2.660]
# 1/1 [==============================] - 0s 42ms/step
# >83, c[0.740,50], d[0.002,0.072], g[2.692]
# 1/1 [==============================] - 0s 36ms/step
# >84, c[0.612,75], d[0.002,0.069], g[2.738]
# 1/1 [==============================] - 0s 32ms/step
# >85, c[0.671,62], d[0.002,0.064], g[2.783]
# 1/1 [==============================] - 0s 34ms/step
# >86, c[0.664,62], d[0.002,0.062], g[2.853]
# 1/1 [==============================] - 0s 33ms/step
# >87, c[0.777,44], d[0.002,0.059], g[2.902]
# 1/1 [==============================] - 0s 41ms/step
# >88, c[0.787,31], d[0.002,0.056], g[2.972]
# 1/1 [==============================] - 0s 37ms/step
# >89, c[0.641,69], d[0.001,0.056], g[3.001]
# 1/1 [==============================] - 0s 34ms/step
# >90, c[0.703,44], d[0.002,0.053], g[3.021]
# 1/1 [==============================] - 0s 34ms/step
# >91, c[0.697,50], d[0.001,0.047], g[3.070]
# 1/1 [==============================] - 0s 35ms/step
# >92, c[0.676,62], d[0.001,0.045], g[3.156]
# 1/1 [==============================] - 0s 34ms/step
# >93, c[0.817,44], d[0.001,0.044], g[3.200]
# 1/1 [==============================] - 0s 36ms/step
# >94, c[0.794,44], d[0.002,0.040], g[3.217]
# 1/1 [==============================] - 0s 35ms/step
# >95, c[0.638,62], d[0.001,0.038], g[3.302]
# 1/1 [==============================] - 0s 36ms/step
# >96, c[0.665,69], d[0.001,0.037], g[3.346]
# 1/1 [==============================] - 0s 36ms/step
# >97, c[0.686,44], d[0.001,0.034], g[3.399]
# 1/1 [==============================] - 0s 34ms/step
# >98, c[0.619,56], d[0.001,0.034], g[3.421]
# 1/1 [==============================] - 0s 33ms/step
# >99, c[0.759,56], d[0.001,0.031], g[3.427]
# 1/1 [==============================] - 0s 34ms/step
# >100, c[0.854,31], d[0.001,0.030], g[3.516]
# 1/1 [==============================] - 0s 33ms/step
# >101, c[0.741,56], d[0.001,0.034], g[3.548]
# 1/1 [==============================] - 0s 33ms/step
# >102, c[0.768,38], d[0.002,0.026], g[3.583]
# 1/1 [==============================] - 0s 47ms/step
# >103, c[0.770,38], d[0.002,0.026], g[3.614]
# 1/1 [==============================] - 0s 46ms/step
# >104, c[0.801,31], d[0.002,0.027], g[3.688]
# 1/1 [==============================] - 0s 40ms/step
# >105, c[0.711,56], d[0.002,0.026], g[3.669]
# 1/1 [==============================] - 0s 37ms/step
# >106, c[0.819,44], d[0.002,0.025], g[3.719]
# 1/1 [==============================] - 0s 42ms/step
# >107, c[0.737,31], d[0.002,0.023], g[3.838]
# 1/1 [==============================] - 0s 36ms/step
# >108, c[0.623,69], d[0.002,0.024], g[3.780]
# 1/1 [==============================] - 0s 43ms/step
# >109, c[0.706,50], d[0.002,0.023], g[3.904]
# 1/1 [==============================] - 0s 38ms/step
# >110, c[0.666,62], d[0.002,0.020], g[3.866]
# 1/1 [==============================] - 0s 53ms/step
# >111, c[0.714,44], d[0.002,0.019], g[3.940]
# 1/1 [==============================] - 0s 65ms/step
# >112, c[0.645,62], d[0.002,0.019], g[3.914]
# 1/1 [==============================] - 0s 79ms/step
# >113, c[0.755,38], d[0.002,0.021], g[3.979]
# 1/1 [==============================] - 0s 50ms/step
# >114, c[0.750,50], d[0.002,0.020], g[4.051]
# 1/1 [==============================] - 0s 45ms/step
# >115, c[0.705,56], d[0.002,0.018], g[4.078]
# 1/1 [==============================] - 0s 40ms/step
# >116, c[0.702,50], d[0.002,0.017], g[4.061]
# 1/1 [==============================] - 0s 81ms/step
# >117, c[0.705,56], d[0.002,0.016], g[4.120]
# 1/1 [==============================] - 0s 50ms/step
# >118, c[0.817,44], d[0.002,0.016], g[4.154]
# 1/1 [==============================] - 0s 61ms/step
# >119, c[0.729,50], d[0.002,0.017], g[4.132]
# 1/1 [==============================] - 0s 41ms/step
# >120, c[0.630,69], d[0.002,0.016], g[4.154]
# 1/1 [==============================] - 0s 62ms/step
# >121, c[0.749,44], d[0.002,0.016], g[4.244]
# 1/1 [==============================] - 0s 53ms/step
# >122, c[0.716,50], d[0.002,0.014], g[4.263]
# 1/1 [==============================] - 0s 32ms/step
# >123, c[0.677,69], d[0.001,0.012], g[4.308]
# 1/1 [==============================] - 0s 56ms/step
# >124, c[0.737,44], d[0.002,0.013], g[4.370]
# 1/1 [==============================] - 0s 44ms/step
# >125, c[0.729,56], d[0.002,0.012], g[4.464]
# 1/1 [==============================] - 0s 37ms/step
# >126, c[0.725,44], d[0.002,0.013], g[4.398]
# 1/1 [==============================] - 0s 47ms/step
# >127, c[0.657,62], d[0.001,0.013], g[4.499]
# 1/1 [==============================] - 0s 48ms/step
# >128, c[0.735,56], d[0.001,0.012], g[4.514]
# 1/1 [==============================] - 0s 45ms/step
# >129, c[0.660,50], d[0.002,0.010], g[4.562]
# 1/1 [==============================] - 0s 44ms/step
# >130, c[0.766,44], d[0.002,0.011], g[4.580]
# 1/1 [==============================] - 0s 50ms/step
# >131, c[0.754,50], d[0.002,0.010], g[4.576]
# 1/1 [==============================] - 0s 33ms/step
# >132, c[0.679,44], d[0.002,0.010], g[4.578]
# 1/1 [==============================] - 0s 34ms/step
# >133, c[0.738,44], d[0.002,0.010], g[4.649]
# 1/1 [==============================] - 0s 34ms/step
# >134, c[0.604,69], d[0.001,0.010], g[4.662]
# 1/1 [==============================] - 0s 34ms/step
# >135, c[0.734,44], d[0.002,0.010], g[4.726]
# 1/1 [==============================] - 0s 35ms/step
# >136, c[0.790,38], d[0.002,0.009], g[4.753]
# 1/1 [==============================] - 0s 34ms/step
# >137, c[0.764,38], d[0.002,0.008], g[4.733]
# 1/1 [==============================] - 0s 35ms/step
# >138, c[0.651,75], d[0.002,0.009], g[4.800]
# 1/1 [==============================] - 0s 34ms/step
# >139, c[0.733,38], d[0.002,0.008], g[4.844]
# 1/1 [==============================] - 0s 37ms/step
# >140, c[0.736,38], d[0.002,0.007], g[4.875]
# 1/1 [==============================] - 0s 33ms/step
# >141, c[0.708,44], d[0.002,0.008], g[4.905]
# 1/1 [==============================] - 0s 35ms/step
# >142, c[0.689,62], d[0.002,0.008], g[4.916]
# 1/1 [==============================] - 0s 35ms/step
# >143, c[0.783,31], d[0.002,0.007], g[5.003]
# 1/1 [==============================] - 0s 35ms/step
# >144, c[0.654,56], d[0.002,0.006], g[5.034]
# 1/1 [==============================] - 0s 36ms/step
# >145, c[0.755,31], d[0.002,0.007], g[4.966]
# 1/1 [==============================] - 0s 35ms/step
# >146, c[0.740,44], d[0.002,0.006], g[4.954]
# 1/1 [==============================] - 0s 34ms/step
# >147, c[0.728,56], d[0.002,0.006], g[5.071]
# 1/1 [==============================] - 0s 33ms/step
# >148, c[0.739,50], d[0.002,0.007], g[5.081]
# 1/1 [==============================] - 0s 34ms/step
# >149, c[0.613,69], d[0.002,0.006], g[5.124]
# 1/1 [==============================] - 0s 36ms/step
# >150, c[0.678,69], d[0.002,0.007], g[5.104]
# 1/1 [==============================] - 0s 33ms/step
# >151, c[0.705,44], d[0.001,0.007], g[5.127]
# 1/1 [==============================] - 0s 35ms/step
# >152, c[0.724,50], d[0.002,0.006], g[5.168]
# 1/1 [==============================] - 0s 38ms/step
# >153, c[0.731,44], d[0.002,0.006], g[5.127]
# 1/1 [==============================] - 0s 37ms/step
# >154, c[0.670,56], d[0.001,0.006], g[5.209]
# 1/1 [==============================] - 0s 34ms/step
# >155, c[0.684,62], d[0.001,0.006], g[5.231]
# 1/1 [==============================] - 0s 33ms/step
# >156, c[0.707,62], d[0.001,0.006], g[5.241]
# 1/1 [==============================] - 0s 36ms/step
# >157, c[0.798,44], d[0.002,0.005], g[5.224]
# 1/1 [==============================] - 0s 35ms/step
# >158, c[0.844,38], d[0.002,0.006], g[5.291]
# 1/1 [==============================] - 0s 36ms/step
# >159, c[0.720,56], d[0.002,0.005], g[5.395]
# 1/1 [==============================] - 0s 34ms/step
# >160, c[0.664,62], d[0.002,0.005], g[5.305]
# 1/1 [==============================] - 0s 37ms/step
# >161, c[0.661,56], d[0.002,0.005], g[5.391]
# 1/1 [==============================] - 0s 40ms/step
# >162, c[0.722,44], d[0.002,0.004], g[5.397]
# 1/1 [==============================] - 0s 46ms/step
# >163, c[0.652,62], d[0.002,0.004], g[5.360]
# 1/1 [==============================] - 0s 34ms/step
# >164, c[0.654,56], d[0.001,0.005], g[5.419]
# 1/1 [==============================] - 0s 35ms/step
# >165, c[0.662,56], d[0.002,0.005], g[5.435]
# 1/1 [==============================] - 0s 34ms/step
# >166, c[0.716,44], d[0.001,0.004], g[5.440]
# 1/1 [==============================] - 0s 45ms/step
# >167, c[0.709,50], d[0.001,0.004], g[5.457]
# 1/1 [==============================] - 0s 50ms/step
# >168, c[0.757,38], d[0.001,0.004], g[5.472]
# 1/1 [==============================] - 0s 37ms/step
# >169, c[0.699,50], d[0.001,0.004], g[5.664]
# 1/1 [==============================] - 0s 39ms/step
# >170, c[0.711,38], d[0.001,0.004], g[5.523]
# 1/1 [==============================] - 0s 35ms/step
# >171, c[0.651,56], d[0.001,0.005], g[5.662]
# 1/1 [==============================] - 0s 33ms/step
# >172, c[0.709,50], d[0.001,0.004], g[5.606]
# 1/1 [==============================] - 0s 39ms/step
# >173, c[0.699,44], d[0.001,0.004], g[5.630]
# 1/1 [==============================] - 0s 45ms/step
# >174, c[0.846,25], d[0.001,0.004], g[5.664]
# 1/1 [==============================] - 0s 46ms/step
# >175, c[0.688,69], d[0.001,0.004], g[5.681]
# 1/1 [==============================] - 0s 42ms/step
# >176, c[0.701,56], d[0.001,0.003], g[5.651]
# 1/1 [==============================] - 0s 79ms/step
# >177, c[0.662,62], d[0.001,0.004], g[5.793]
# 1/1 [==============================] - 0s 44ms/step
# >178, c[0.680,62], d[0.001,0.003], g[5.850]
# 1/1 [==============================] - 0s 34ms/step
# >179, c[0.804,44], d[0.002,0.003], g[5.784]
# 1/1 [==============================] - 0s 56ms/step
# >180, c[0.697,50], d[0.002,0.003], g[5.766]
# 1/1 [==============================] - 0s 39ms/step
# >181, c[0.637,62], d[0.001,0.003], g[5.815]
# 1/1 [==============================] - 0s 37ms/step
# >182, c[0.716,56], d[0.001,0.003], g[5.824]
# 1/1 [==============================] - 0s 36ms/step
# >183, c[0.755,50], d[0.001,0.003], g[5.938]
# 1/1 [==============================] - 0s 37ms/step
# >184, c[0.769,38], d[0.001,0.003], g[5.836]
# 1/1 [==============================] - 0s 35ms/step
# >185, c[0.651,69], d[0.001,0.003], g[5.846]
# 1/1 [==============================] - 0s 39ms/step
# >186, c[0.711,44], d[0.002,0.003], g[5.902]
# 1/1 [==============================] - 0s 36ms/step
# >187, c[0.750,56], d[0.001,0.003], g[5.988]
# 1/1 [==============================] - 0s 36ms/step
# >188, c[0.711,56], d[0.001,0.002], g[5.959]
# 1/1 [==============================] - 0s 35ms/step
# >189, c[0.720,62], d[0.002,0.002], g[6.094]
# 1/1 [==============================] - 0s 48ms/step
# >190, c[0.703,62], d[0.001,0.002], g[6.027]
# 1/1 [==============================] - 0s 39ms/step
# >191, c[0.610,56], d[0.001,0.003], g[6.089]
# 1/1 [==============================] - 0s 38ms/step
# >192, c[0.626,62], d[0.001,0.002], g[6.009]
# 1/1 [==============================] - 0s 36ms/step
# >193, c[0.573,75], d[0.001,0.003], g[6.078]
# 1/1 [==============================] - 0s 42ms/step
# >194, c[0.605,69], d[0.001,0.002], g[6.130]
# 1/1 [==============================] - 0s 35ms/step
# >195, c[0.657,62], d[0.001,0.003], g[6.121]
# 1/1 [==============================] - 0s 43ms/step
# >196, c[0.752,56], d[0.001,0.002], g[6.137]
# 1/1 [==============================] - 0s 34ms/step
# >197, c[0.832,44], d[0.001,0.002], g[6.130]
# 1/1 [==============================] - 0s 38ms/step
# >198, c[0.687,56], d[0.001,0.002], g[6.129]
# 1/1 [==============================] - 0s 35ms/step
# >199, c[0.720,44], d[0.001,0.002], g[6.242]
# 1/1 [==============================] - 0s 34ms/step
# >200, c[0.651,50], d[0.001,0.002], g[6.283]
# 1/1 [==============================] - 0s 36ms/step
# >201, c[0.622,75], d[0.001,0.002], g[6.247]
# 1/1 [==============================] - 0s 35ms/step
# >202, c[0.797,44], d[0.001,0.002], g[6.267]
# 1/1 [==============================] - 0s 36ms/step
# >203, c[0.794,50], d[0.001,0.002], g[6.309]
# 1/1 [==============================] - 0s 36ms/step
# >204, c[0.700,56], d[0.001,0.002], g[6.371]
# 1/1 [==============================] - 0s 42ms/step
# >205, c[0.662,50], d[0.001,0.002], g[6.333]
# 1/1 [==============================] - 0s 36ms/step
# >206, c[0.607,81], d[0.001,0.002], g[6.330]
# 1/1 [==============================] - 0s 43ms/step
# >207, c[0.676,56], d[0.001,0.002], g[6.301]
# 1/1 [==============================] - 0s 40ms/step
# >208, c[0.685,50], d[0.001,0.002], g[6.319]
# 1/1 [==============================] - 0s 41ms/step
# >209, c[0.792,38], d[0.001,0.002], g[6.384]
# 1/1 [==============================] - 0s 37ms/step
# >210, c[0.780,38], d[0.001,0.002], g[6.373]
# 1/1 [==============================] - 0s 47ms/step
# >211, c[0.730,44], d[0.001,0.002], g[6.401]
# 1/1 [==============================] - 0s 39ms/step
# >212, c[0.679,69], d[0.001,0.002], g[6.456]
# 1/1 [==============================] - 0s 37ms/step
# >213, c[0.726,44], d[0.001,0.002], g[6.488]
# 1/1 [==============================] - 0s 36ms/step
# >214, c[0.651,69], d[0.001,0.002], g[6.474]
# 1/1 [==============================] - 0s 33ms/step
# >215, c[0.751,38], d[0.001,0.002], g[6.462]
# 1/1 [==============================] - 0s 33ms/step
# >216, c[0.656,69], d[0.001,0.002], g[6.466]
# 1/1 [==============================] - 0s 36ms/step
# >217, c[0.697,50], d[0.001,0.001], g[6.527]
# 1/1 [==============================] - 0s 33ms/step
# >218, c[0.642,75], d[0.001,0.001], g[6.520]
# 1/1 [==============================] - 0s 35ms/step
# >219, c[0.771,56], d[0.001,0.002], g[6.542]
# 1/1 [==============================] - 0s 34ms/step
# >220, c[0.718,50], d[0.001,0.001], g[6.571]
# 1/1 [==============================] - 0s 71ms/step
# >221, c[0.607,69], d[0.001,0.001], g[6.632]
# 1/1 [==============================] - 0s 36ms/step
# >222, c[0.797,50], d[0.001,0.001], g[6.669]
# 1/1 [==============================] - 0s 35ms/step
# >223, c[0.816,38], d[0.001,0.001], g[6.681]
# 1/1 [==============================] - 0s 35ms/step
# >224, c[0.814,25], d[0.002,0.001], g[6.691]
# 1/1 [==============================] - 0s 35ms/step
# >225, c[0.758,50], d[0.002,0.001], g[6.786]
# 1/1 [==============================] - 0s 34ms/step
# >226, c[0.702,69], d[0.002,0.001], g[6.734]
# 1/1 [==============================] - 0s 35ms/step
# >227, c[0.731,38], d[0.002,0.001], g[6.764]
# 1/1 [==============================] - 0s 35ms/step
# >228, c[0.719,44], d[0.002,0.001], g[6.806]
# 1/1 [==============================] - 0s 34ms/step
# >229, c[0.755,50], d[0.002,0.001], g[6.785]
# 1/1 [==============================] - 0s 34ms/step
# >230, c[0.710,50], d[0.002,0.001], g[6.834]
# 1/1 [==============================] - 0s 36ms/step
# >231, c[0.717,38], d[0.002,0.001], g[6.847]
# 1/1 [==============================] - 0s 34ms/step
# >232, c[0.677,69], d[0.002,0.001], g[6.969]
# 1/1 [==============================] - 0s 37ms/step
# >233, c[0.649,56], d[0.002,0.001], g[7.034]
# 1/1 [==============================] - 0s 34ms/step
# >234, c[0.664,56], d[0.001,0.001], g[6.928]
# 1/1 [==============================] - 0s 47ms/step
# >235, c[0.719,50], d[0.001,0.001], g[6.846]
# 1/1 [==============================] - 0s 35ms/step
# >236, c[0.714,50], d[0.001,0.001], g[6.965]
# 1/1 [==============================] - 0s 35ms/step
# >237, c[0.702,50], d[0.001,0.001], g[7.020]
# 1/1 [==============================] - 0s 35ms/step
# >238, c[0.681,44], d[0.001,0.001], g[6.903]
# 1/1 [==============================] - 0s 36ms/step
# >239, c[0.681,50], d[0.001,0.001], g[6.971]
# 1/1 [==============================] - 0s 96ms/step
# >240, c[0.688,44], d[0.001,0.001], g[6.975]
# 1/1 [==============================] - 0s 37ms/step
# >241, c[0.745,31], d[0.001,0.001], g[6.944]
# 1/1 [==============================] - 0s 37ms/step
# >242, c[0.741,50], d[0.001,0.001], g[7.041]
# 1/1 [==============================] - 0s 47ms/step
# >243, c[0.738,44], d[0.001,0.001], g[7.071]
# 1/1 [==============================] - 0s 41ms/step
# >244, c[0.748,44], d[0.001,0.001], g[7.168]
# 1/1 [==============================] - 0s 47ms/step
# >245, c[0.726,38], d[0.001,0.001], g[7.228]
# 1/1 [==============================] - 0s 48ms/step
# >246, c[0.683,62], d[0.001,0.001], g[7.142]
# 1/1 [==============================] - 0s 48ms/step
# >247, c[0.736,50], d[0.001,0.001], g[7.172]
# 1/1 [==============================] - 0s 56ms/step
# >248, c[0.720,44], d[0.001,0.001], g[7.201]
# 1/1 [==============================] - 0s 36ms/step
# >249, c[0.660,56], d[0.001,0.001], g[7.286]
# 1/1 [==============================] - 0s 43ms/step
# >250, c[0.730,44], d[0.001,0.001], g[7.227]
# 1/1 [==============================] - 0s 51ms/step
# >251, c[0.709,56], d[0.001,0.001], g[7.289]
# 1/1 [==============================] - 0s 131ms/step
# >252, c[0.670,56], d[0.001,0.001], g[7.190]
# 1/1 [==============================] - 0s 46ms/step
# >253, c[0.770,56], d[0.002,0.001], g[7.227]
# 1/1 [==============================] - 0s 39ms/step
# >254, c[0.786,44], d[0.002,0.001], g[7.331]
# 1/1 [==============================] - 0s 39ms/step
# >255, c[0.742,50], d[0.002,0.001], g[7.462]
# 1/1 [==============================] - 0s 43ms/step
# >256, c[0.722,44], d[0.002,0.001], g[7.285]
# 1/1 [==============================] - 0s 43ms/step
# >257, c[0.725,44], d[0.002,0.001], g[7.428]
# 1/1 [==============================] - 0s 36ms/step
# >258, c[0.649,62], d[0.002,0.001], g[7.479]
# 1/1 [==============================] - 0s 35ms/step
# >259, c[0.728,31], d[0.002,0.001], g[7.351]
# 1/1 [==============================] - 0s 40ms/step
# >260, c[0.795,44], d[0.002,0.001], g[7.580]
# 1/1 [==============================] - 0s 42ms/step
# >261, c[0.708,50], d[0.002,0.001], g[7.600]
# 1/1 [==============================] - 0s 43ms/step
# >262, c[0.788,38], d[0.002,0.001], g[7.591]
# 1/1 [==============================] - 0s 38ms/step
# >263, c[0.701,50], d[0.002,0.001], g[7.599]
# 1/1 [==============================] - 0s 35ms/step
# >264, c[0.709,69], d[0.002,0.000], g[7.748]
# 1/1 [==============================] - 0s 37ms/step
# >265, c[0.736,44], d[0.002,0.000], g[7.702]
# 1/1 [==============================] - 0s 45ms/step
# >266, c[0.653,69], d[0.002,0.000], g[7.740]
# 1/1 [==============================] - 0s 60ms/step
# >267, c[0.773,56], d[0.002,0.000], g[7.806]
# 1/1 [==============================] - 0s 36ms/step
# >268, c[0.775,38], d[0.002,0.000], g[7.775]
# 1/1 [==============================] - 0s 34ms/step
# >269, c[0.626,69], d[0.002,0.000], g[7.915]
# 1/1 [==============================] - 0s 37ms/step
# >270, c[0.738,44], d[0.002,0.000], g[7.719]
# 1/1 [==============================] - 0s 35ms/step
# >271, c[0.597,69], d[0.001,0.000], g[7.928]
# 1/1 [==============================] - 0s 33ms/step
# >272, c[0.721,50], d[0.001,0.000], g[7.960]
# 1/1 [==============================] - 0s 35ms/step
# >273, c[0.803,25], d[0.001,0.000], g[8.027]
# 1/1 [==============================] - 0s 35ms/step
# >274, c[0.653,62], d[0.001,0.000], g[8.070]
# 1/1 [==============================] - 0s 34ms/step
# >275, c[0.679,56], d[0.001,0.000], g[8.037]
# 1/1 [==============================] - 0s 34ms/step
# >276, c[0.679,62], d[0.001,0.000], g[8.025]
# 1/1 [==============================] - 0s 34ms/step
# >277, c[0.785,38], d[0.001,0.000], g[7.961]
# 1/1 [==============================] - 0s 36ms/step
# >278, c[0.633,56], d[0.001,0.000], g[8.012]
# 1/1 [==============================] - 0s 34ms/step
# >279, c[0.658,50], d[0.001,0.000], g[8.070]
# 1/1 [==============================] - 0s 36ms/step
# >280, c[0.703,56], d[0.001,0.000], g[7.996]
# 1/1 [==============================] - 0s 34ms/step
# >281, c[0.626,62], d[0.001,0.000], g[8.021]
# 1/1 [==============================] - 0s 35ms/step
# >282, c[0.738,56], d[0.001,0.000], g[8.156]
# 1/1 [==============================] - 0s 34ms/step
# >283, c[0.697,44], d[0.001,0.000], g[8.118]
# 1/1 [==============================] - 0s 38ms/step
# >284, c[0.759,31], d[0.001,0.000], g[8.292]
# 1/1 [==============================] - 0s 62ms/step
# >285, c[0.689,62], d[0.001,0.000], g[8.093]
# 1/1 [==============================] - 0s 38ms/step
# >286, c[0.644,56], d[0.001,0.000], g[8.270]
# 1/1 [==============================] - 0s 57ms/step
# >287, c[0.719,44], d[0.001,0.000], g[8.146]
# 1/1 [==============================] - 0s 38ms/step
# >288, c[0.782,44], d[0.001,0.000], g[8.222]
# 1/1 [==============================] - 0s 42ms/step
# >289, c[0.703,50], d[0.001,0.000], g[8.266]
# 1/1 [==============================] - 0s 35ms/step
# >290, c[0.717,56], d[0.001,0.000], g[8.285]
# 1/1 [==============================] - 0s 42ms/step
# >291, c[0.739,50], d[0.001,0.000], g[8.200]
# 1/1 [==============================] - 0s 39ms/step
# >292, c[0.707,56], d[0.001,0.000], g[8.418]
# 1/1 [==============================] - 0s 34ms/step
# >293, c[0.762,44], d[0.002,0.000], g[8.457]
# 1/1 [==============================] - 0s 32ms/step
# >294, c[0.713,44], d[0.002,0.000], g[8.478]
# 1/1 [==============================] - 0s 36ms/step
# >295, c[0.792,44], d[0.002,0.000], g[8.529]
# 1/1 [==============================] - 0s 33ms/step
# >296, c[0.800,25], d[0.002,0.000], g[8.688]
# 1/1 [==============================] - 0s 35ms/step
# >297, c[0.710,50], d[0.002,0.000], g[8.566]
# 1/1 [==============================] - 0s 41ms/step
# >298, c[0.792,50], d[0.002,0.000], g[8.752]
# 1/1 [==============================] - 0s 36ms/step
# >299, c[0.811,31], d[0.003,0.000], g[8.774]
# 1/1 [==============================] - 0s 37ms/step
# >300, c[0.690,50], d[0.002,0.000], g[8.710]
# 1/1 [==============================] - 0s 35ms/step
# >301, c[0.742,38], d[0.002,0.000], g[8.785]
# 1/1 [==============================] - 0s 43ms/step
# >302, c[0.739,44], d[0.002,0.000], g[8.861]
# 1/1 [==============================] - 0s 47ms/step
# >303, c[0.760,50], d[0.003,0.000], g[8.933]
# 1/1 [==============================] - 0s 35ms/step
# >304, c[0.770,38], d[0.003,0.000], g[9.157]
# 1/1 [==============================] - 0s 35ms/step
# >305, c[0.783,44], d[0.003,0.000], g[9.087]
# 1/1 [==============================] - 0s 35ms/step
# >306, c[0.686,69], d[0.002,0.000], g[9.192]
# 1/1 [==============================] - 0s 34ms/step
# >307, c[0.701,50], d[0.003,0.000], g[9.237]
# 1/1 [==============================] - 0s 35ms/step
# >308, c[0.577,69], d[0.002,0.000], g[9.276]
# 1/1 [==============================] - 0s 35ms/step
# >309, c[0.756,38], d[0.001,0.000], g[9.202]
# 1/1 [==============================] - 0s 36ms/step
# >310, c[0.664,62], d[0.001,0.000], g[9.365]
# 1/1 [==============================] - 0s 34ms/step
# >311, c[0.674,50], d[0.001,0.000], g[9.230]
# 1/1 [==============================] - 0s 37ms/step
# >312, c[0.768,44], d[0.001,0.000], g[9.240]
# 1/1 [==============================] - 0s 39ms/step
# >313, c[0.769,44], d[0.001,0.000], g[9.143]
# 1/1 [==============================] - 0s 38ms/step
# >314, c[0.680,75], d[0.001,0.000], g[9.317]
# 1/1 [==============================] - 0s 40ms/step
# >315, c[0.829,38], d[0.001,0.000], g[9.286]
# 1/1 [==============================] - 0s 34ms/step
# >316, c[0.782,31], d[0.002,0.000], g[9.482]
# 1/1 [==============================] - 0s 36ms/step
# >317, c[0.630,62], d[0.002,0.000], g[9.329]
# 1/1 [==============================] - 0s 35ms/step
# >318, c[0.650,62], d[0.001,0.000], g[9.382]
# 1/1 [==============================] - 0s 41ms/step
# >319, c[0.731,38], d[0.001,0.000], g[9.595]
# 1/1 [==============================] - 0s 36ms/step
# >320, c[0.632,56], d[0.001,0.000], g[9.437]
# 1/1 [==============================] - 0s 35ms/step
# >321, c[0.890,38], d[0.002,0.000], g[9.552]
# 1/1 [==============================] - 0s 39ms/step
# >322, c[0.727,62], d[0.001,0.000], g[9.516]
# 1/1 [==============================] - 0s 48ms/step
# >323, c[0.773,38], d[0.002,0.000], g[9.658]
# 1/1 [==============================] - 0s 39ms/step
# >324, c[0.653,62], d[0.001,0.000], g[9.639]
# 1/1 [==============================] - 0s 34ms/step
# >325, c[0.711,56], d[0.001,0.000], g[9.634]
# 1/1 [==============================] - 0s 36ms/step
# >326, c[0.702,50], d[0.001,0.000], g[9.694]
# 1/1 [==============================] - 0s 35ms/step
# >327, c[0.751,50], d[0.001,0.000], g[9.580]
# 1/1 [==============================] - 0s 35ms/step
# >328, c[0.669,69], d[0.001,0.000], g[9.672]
# 1/1 [==============================] - 0s 33ms/step
# >329, c[0.724,44], d[0.001,0.000], g[9.757]
# 1/1 [==============================] - 0s 38ms/step
# >330, c[0.637,56], d[0.001,0.000], g[9.624]
# 1/1 [==============================] - 0s 35ms/step
# >331, c[0.845,31], d[0.001,0.000], g[9.633]
# 1/1 [==============================] - 0s 36ms/step
# >332, c[0.688,56], d[0.001,0.000], g[9.784]
# 1/1 [==============================] - 0s 35ms/step
# >333, c[0.666,56], d[0.001,0.000], g[9.739]
# 1/1 [==============================] - 0s 34ms/step
# >334, c[0.716,50], d[0.001,0.000], g[9.796]
# 1/1 [==============================] - 0s 34ms/step
# >335, c[0.799,38], d[0.001,0.000], g[9.814]
# 1/1 [==============================] - 0s 35ms/step
# >336, c[0.656,75], d[0.001,0.000], g[9.982]
# 1/1 [==============================] - 0s 33ms/step
# >337, c[0.720,44], d[0.001,0.000], g[9.953]
# 1/1 [==============================] - 0s 49ms/step
# >338, c[0.780,44], d[0.001,0.000], g[9.907]
# 1/1 [==============================] - 0s 37ms/step
# >339, c[0.686,69], d[0.001,0.000], g[9.874]
# 1/1 [==============================] - 0s 44ms/step
# >340, c[0.634,69], d[0.001,0.000], g[9.928]
# 1/1 [==============================] - 0s 46ms/step
# >341, c[0.795,50], d[0.001,0.000], g[10.052]
# 1/1 [==============================] - 0s 38ms/step
# >342, c[0.842,38], d[0.002,0.000], g[10.113]
# 1/1 [==============================] - 0s 35ms/step
# >343, c[0.646,62], d[0.001,0.000], g[10.262]
# 1/1 [==============================] - 0s 35ms/step
# >344, c[0.650,62], d[0.001,0.000], g[10.068]
# 1/1 [==============================] - 0s 34ms/step
# >345, c[0.735,38], d[0.001,0.000], g[10.042]
# 1/1 [==============================] - 0s 34ms/step
# >346, c[0.703,56], d[0.001,0.000], g[10.049]
# 1/1 [==============================] - 0s 34ms/step
# >347, c[0.749,44], d[0.001,0.000], g[10.113]
# 1/1 [==============================] - 0s 35ms/step
# >348, c[0.635,62], d[0.001,0.000], g[10.129]
# 1/1 [==============================] - 0s 36ms/step
# >349, c[0.645,69], d[0.001,0.000], g[10.082]
# 1/1 [==============================] - 0s 33ms/step
# >350, c[0.760,44], d[0.001,0.000], g[10.149]
# 1/1 [==============================] - 0s 32ms/step
# >351, c[0.716,56], d[0.001,0.000], g[10.370]
# 1/1 [==============================] - 0s 34ms/step
# >352, c[0.739,44], d[0.001,0.000], g[10.379]
# 1/1 [==============================] - 0s 37ms/step
# >353, c[0.650,56], d[0.001,0.000], g[10.273]
# 1/1 [==============================] - 0s 35ms/step
# >354, c[0.853,31], d[0.001,0.000], g[10.350]
# 1/1 [==============================] - 0s 42ms/step
# >355, c[0.771,38], d[0.001,0.000], g[10.377]
# 1/1 [==============================] - 0s 43ms/step
# >356, c[0.678,56], d[0.002,0.000], g[10.271]
# 1/1 [==============================] - 0s 36ms/step
# >357, c[0.601,75], d[0.001,0.000], g[10.423]
# 1/1 [==============================] - 0s 43ms/step
# >358, c[0.644,62], d[0.001,0.000], g[10.375]
# 1/1 [==============================] - 0s 39ms/step
# >359, c[0.596,69], d[0.001,0.000], g[10.569]
# 1/1 [==============================] - 0s 39ms/step
# >360, c[0.766,50], d[0.001,0.000], g[10.483]
# 1/1 [==============================] - 0s 38ms/step
# >361, c[0.762,44], d[0.001,0.000], g[10.435]
# 1/1 [==============================] - 0s 35ms/step
# >362, c[0.659,50], d[0.001,0.000], g[10.434]
# 1/1 [==============================] - 0s 36ms/step
# >363, c[0.688,62], d[0.001,0.000], g[10.501]
# 1/1 [==============================] - 0s 36ms/step
# >364, c[0.714,44], d[0.000,0.000], g[10.343]
# 1/1 [==============================] - 0s 42ms/step
# >365, c[0.769,50], d[0.001,0.000], g[10.385]
# 1/1 [==============================] - 0s 55ms/step
# >366, c[0.727,50], d[0.000,0.000], g[10.530]
# 1/1 [==============================] - 0s 43ms/step
# >367, c[0.857,38], d[0.001,0.000], g[10.434]
# 1/1 [==============================] - 0s 43ms/step
# >368, c[0.780,38], d[0.001,0.000], g[10.664]
# 1/1 [==============================] - 0s 50ms/step
# >369, c[0.781,38], d[0.001,0.000], g[10.593]
# 1/1 [==============================] - 0s 42ms/step
# >370, c[0.703,56], d[0.001,0.000], g[10.629]
# 1/1 [==============================] - 0s 53ms/step
# >371, c[0.799,44], d[0.002,0.000], g[10.576]
# 1/1 [==============================] - 0s 46ms/step
# >372, c[0.854,19], d[0.002,0.000], g[10.741]
# 1/1 [==============================] - 0s 69ms/step
# >373, c[0.710,44], d[0.002,0.000], g[10.770]
# 1/1 [==============================] - 0s 41ms/step
# >374, c[0.721,50], d[0.001,0.000], g[10.794]
# 1/1 [==============================] - 0s 51ms/step
# >375, c[0.679,62], d[0.001,0.000], g[10.710]
# 1/1 [==============================] - 0s 40ms/step
# >376, c[0.768,38], d[0.001,0.000], g[10.849]
# 1/1 [==============================] - 0s 46ms/step
# >377, c[0.757,50], d[0.001,0.000], g[10.884]
# 1/1 [==============================] - 0s 44ms/step
# >378, c[0.717,44], d[0.001,0.000], g[10.861]
# 1/1 [==============================] - 0s 39ms/step
# >379, c[0.755,44], d[0.001,0.000], g[10.801]
# 1/1 [==============================] - 0s 33ms/step
# >380, c[0.680,62], d[0.001,0.000], g[11.115]
# 1/1 [==============================] - 0s 34ms/step
# >381, c[0.700,56], d[0.001,0.000], g[11.035]
# 1/1 [==============================] - 0s 34ms/step
# >382, c[0.704,56], d[0.001,0.000], g[11.164]
# 1/1 [==============================] - 0s 35ms/step
# >383, c[0.685,50], d[0.001,0.000], g[11.137]
# 1/1 [==============================] - 0s 44ms/step
# >384, c[0.780,38], d[0.001,0.000], g[11.298]
# 1/1 [==============================] - 0s 41ms/step
# >385, c[0.596,62], d[0.001,0.000], g[11.188]
# 1/1 [==============================] - 0s 35ms/step
# >386, c[0.795,38], d[0.001,0.000], g[11.154]
# 1/1 [==============================] - 0s 37ms/step
# >387, c[0.713,56], d[0.001,0.000], g[11.036]
# 1/1 [==============================] - 0s 36ms/step
# >388, c[0.735,50], d[0.001,0.000], g[11.120]
# 1/1 [==============================] - 0s 34ms/step
# >389, c[0.660,62], d[0.001,0.000], g[11.131]
# 1/1 [==============================] - 0s 38ms/step
# >390, c[0.772,50], d[0.001,0.000], g[11.234]
# 1/1 [==============================] - 0s 33ms/step
# >391, c[0.750,31], d[0.001,0.000], g[11.224]
# 1/1 [==============================] - 0s 69ms/step
# >392, c[0.664,50], d[0.001,0.000], g[11.113]
# 1/1 [==============================] - 0s 53ms/step
# >393, c[0.649,75], d[0.001,0.000], g[10.959]
# 1/1 [==============================] - 0s 40ms/step
# >394, c[0.826,56], d[0.001,0.000], g[11.233]
# 1/1 [==============================] - 0s 43ms/step
# >395, c[0.689,62], d[0.001,0.000], g[11.187]
# 1/1 [==============================] - 0s 41ms/step
# >396, c[0.743,44], d[0.001,0.000], g[11.240]
# 1/1 [==============================] - 0s 50ms/step
# >397, c[0.756,38], d[0.001,0.000], g[11.245]
# 1/1 [==============================] - 0s 41ms/step
# >398, c[0.766,50], d[0.001,0.000], g[11.271]
# 1/1 [==============================] - 0s 42ms/step
# >399, c[0.747,44], d[0.001,0.000], g[11.392]
# 1/1 [==============================] - 0s 40ms/step
# >400, c[0.707,44], d[0.001,0.000], g[11.490]
# 1/1 [==============================] - 0s 39ms/step
# >401, c[0.705,56], d[0.001,0.000], g[11.604]
# 1/1 [==============================] - 0s 47ms/step
# >402, c[0.650,56], d[0.001,0.000], g[11.554]
# 1/1 [==============================] - 0s 37ms/step
# >403, c[0.729,50], d[0.001,0.000], g[11.541]
# 1/1 [==============================] - 0s 42ms/step
# >404, c[0.826,44], d[0.001,0.000], g[11.541]
# 1/1 [==============================] - 0s 50ms/step
# >405, c[0.743,50], d[0.001,0.000], g[11.659]
# 1/1 [==============================] - 0s 39ms/step
# >406, c[0.709,44], d[0.001,0.000], g[11.721]
# 1/1 [==============================] - 0s 39ms/step
# >407, c[0.614,69], d[0.001,0.000], g[11.505]
# 1/1 [==============================] - 0s 36ms/step
# >408, c[0.654,56], d[0.001,0.000], g[11.738]
# 1/1 [==============================] - 0s 37ms/step
# >409, c[0.953,19], d[0.001,0.000], g[11.750]
# 1/1 [==============================] - 0s 41ms/step
# >410, c[0.682,56], d[0.001,0.000], g[11.668]
# 1/1 [==============================] - 0s 47ms/step
# >411, c[0.694,50], d[0.001,0.000], g[11.760]
# 1/1 [==============================] - 0s 43ms/step
# >412, c[0.674,75], d[0.000,0.000], g[11.555]
# 1/1 [==============================] - 0s 44ms/step
# >413, c[0.642,69], d[0.000,0.000], g[11.710]
# 1/1 [==============================] - 0s 37ms/step
# >414, c[0.669,56], d[0.000,0.000], g[11.621]
# 1/1 [==============================] - 0s 45ms/step
# >415, c[0.666,62], d[0.000,0.000], g[11.630]
# 1/1 [==============================] - 0s 39ms/step
# >416, c[0.642,75], d[0.000,0.000], g[11.856]
# 1/1 [==============================] - 0s 40ms/step
# >417, c[0.626,69], d[0.000,0.000], g[11.684]
# 1/1 [==============================] - 0s 35ms/step
# >418, c[0.719,56], d[0.000,0.000], g[11.576]
# 1/1 [==============================] - 0s 38ms/step
# >419, c[0.591,69], d[0.000,0.000], g[11.676]
# 1/1 [==============================] - 0s 42ms/step
# >420, c[0.763,38], d[0.000,0.000], g[11.656]
# 1/1 [==============================] - 0s 59ms/step
# >421, c[0.651,62], d[0.000,0.000], g[11.712]
# 1/1 [==============================] - 0s 39ms/step
# >422, c[0.765,31], d[0.000,0.000], g[11.731]
# 1/1 [==============================] - 0s 37ms/step
# >423, c[0.705,56], d[0.001,0.000], g[11.898]
# 1/1 [==============================] - 0s 40ms/step
# >424, c[0.794,38], d[0.001,0.000], g[11.955]
# 1/1 [==============================] - 0s 34ms/step
# >425, c[0.752,38], d[0.001,0.000], g[11.949]
# 1/1 [==============================] - 0s 36ms/step
# >426, c[0.654,56], d[0.001,0.000], g[12.017]
# 1/1 [==============================] - 0s 45ms/step
# >427, c[0.715,62], d[0.001,0.000], g[12.007]
# 1/1 [==============================] - 0s 43ms/step
# >428, c[0.618,56], d[0.001,0.000], g[11.915]
# 1/1 [==============================] - 0s 46ms/step
# >429, c[0.698,62], d[0.001,0.000], g[12.009]
# 1/1 [==============================] - 0s 43ms/step
# >430, c[0.664,56], d[0.000,0.000], g[11.911]
# 1/1 [==============================] - 0s 58ms/step
# >431, c[0.647,62], d[0.000,0.000], g[12.023]
# 1/1 [==============================] - 0s 58ms/step
# >432, c[0.776,56], d[0.000,0.000], g[11.949]
# 1/1 [==============================] - 0s 51ms/step
# >433, c[0.778,56], d[0.000,0.000], g[11.918]
# 1/1 [==============================] - 0s 51ms/step
# >434, c[0.623,56], d[0.000,0.000], g[11.911]
# 1/1 [==============================] - 0s 53ms/step
# >435, c[0.732,38], d[0.000,0.000], g[12.012]
# 1/1 [==============================] - 0s 56ms/step
# >436, c[0.743,56], d[0.001,0.000], g[12.199]
# 1/1 [==============================] - 0s 54ms/step
# >437, c[0.769,50], d[0.001,0.000], g[12.182]
# 1/1 [==============================] - 0s 63ms/step
# >438, c[0.700,50], d[0.001,0.000], g[12.163]
# 1/1 [==============================] - 0s 37ms/step
# >439, c[0.765,56], d[0.001,0.000], g[12.225]
# 1/1 [==============================] - 0s 33ms/step
# >440, c[0.816,31], d[0.002,0.000], g[12.197]
# 1/1 [==============================] - 0s 43ms/step
# >441, c[0.676,62], d[0.001,0.000], g[12.427]
# 1/1 [==============================] - 0s 35ms/step
# >442, c[0.731,50], d[0.001,0.000], g[12.232]
# 1/1 [==============================] - 0s 48ms/step
# >443, c[0.732,50], d[0.001,0.000], g[12.342]
# 1/1 [==============================] - 0s 39ms/step
# >444, c[0.607,56], d[0.001,0.000], g[12.403]
# 1/1 [==============================] - 0s 33ms/step
# >445, c[0.653,69], d[0.000,0.000], g[12.469]
# 1/1 [==============================] - 0s 33ms/step
# >446, c[0.608,69], d[0.000,0.000], g[12.215]
# 1/1 [==============================] - 0s 34ms/step
# >447, c[0.845,25], d[0.000,0.000], g[12.371]
# 1/1 [==============================] - 0s 34ms/step
# >448, c[0.649,62], d[0.001,0.000], g[12.389]
# 1/1 [==============================] - 0s 35ms/step
# >449, c[0.722,44], d[0.001,0.000], g[12.433]
# 1/1 [==============================] - 0s 34ms/step
# >450, c[0.762,44], d[0.001,0.000], g[12.492]
# 1/1 [==============================] - 0s 36ms/step
# >451, c[0.755,38], d[0.001,0.000], g[12.651]
# 1/1 [==============================] - 0s 36ms/step
# >452, c[0.747,50], d[0.001,0.000], g[12.701]
# 1/1 [==============================] - 0s 36ms/step
# >453, c[0.717,44], d[0.001,0.000], g[12.501]
# 1/1 [==============================] - 0s 34ms/step
# >454, c[0.842,31], d[0.001,0.000], g[12.646]
# 1/1 [==============================] - 0s 35ms/step
# >455, c[0.745,38], d[0.001,0.000], g[12.611]
# 1/1 [==============================] - 0s 39ms/step
# >456, c[0.708,62], d[0.001,0.000], g[12.698]
# 1/1 [==============================] - 0s 36ms/step
# >457, c[0.729,44], d[0.000,0.000], g[12.786]
# 1/1 [==============================] - 0s 38ms/step
# >458, c[0.670,50], d[0.000,0.000], g[12.647]
# 1/1 [==============================] - 0s 37ms/step
# >459, c[0.718,56], d[0.000,0.000], g[12.558]
# 1/1 [==============================] - 0s 39ms/step
# >460, c[0.889,31], d[0.001,0.000], g[12.732]
# 1/1 [==============================] - 0s 53ms/step
# >461, c[0.696,62], d[0.001,0.000], g[12.681]
# 1/1 [==============================] - 0s 39ms/step
# >462, c[0.702,56], d[0.001,0.000], g[12.606]
# 1/1 [==============================] - 0s 36ms/step
# >463, c[0.719,50], d[0.001,0.000], g[12.716]
# 1/1 [==============================] - 0s 40ms/step
# >464, c[0.697,56], d[0.001,0.000], g[12.915]
# 1/1 [==============================] - 0s 46ms/step
# >465, c[0.668,56], d[0.001,0.000], g[13.080]
# 1/1 [==============================] - 0s 34ms/step
# >466, c[0.697,50], d[0.001,0.000], g[13.193]
# 1/1 [==============================] - 0s 35ms/step
# >467, c[0.740,31], d[0.001,0.000], g[13.001]
# 1/1 [==============================] - 0s 48ms/step
# >468, c[0.763,50], d[0.001,0.000], g[13.230]
# 1/1 [==============================] - 0s 32ms/step
# >469, c[0.645,69], d[0.001,0.000], g[13.150]
# 1/1 [==============================] - 0s 35ms/step
# >470, c[0.878,31], d[0.001,0.000], g[13.020]
# 1/1 [==============================] - 0s 34ms/step
# >471, c[0.678,69], d[0.001,0.000], g[13.110]
# 1/1 [==============================] - 0s 32ms/step
# >472, c[0.875,31], d[0.001,0.000], g[12.942]
# 1/1 [==============================] - 0s 37ms/step
# >473, c[0.667,56], d[0.000,0.000], g[13.309]
# 1/1 [==============================] - 0s 34ms/step
# >474, c[0.665,50], d[0.000,0.000], g[13.144]
# 1/1 [==============================] - 0s 35ms/step
# >475, c[0.740,38], d[0.001,0.000], g[13.123]
# 1/1 [==============================] - 0s 36ms/step
# >476, c[0.803,31], d[0.001,0.000], g[13.296]
# 1/1 [==============================] - 0s 39ms/step
# >477, c[0.638,75], d[0.000,0.000], g[13.357]
# 1/1 [==============================] - 0s 44ms/step
# >478, c[0.710,56], d[0.000,0.000], g[13.200]
# 1/1 [==============================] - 0s 35ms/step
# >479, c[0.733,62], d[0.000,0.000], g[13.291]
# 1/1 [==============================] - 0s 34ms/step
# >480, c[0.721,50], d[0.000,0.000], g[13.271]
# 1/1 [==============================] - 0s 34ms/step
# >481, c[0.559,69], d[0.000,0.000], g[13.221]
# 1/1 [==============================] - 0s 35ms/step
# >482, c[0.717,50], d[0.000,0.000], g[13.098]
# 1/1 [==============================] - 0s 34ms/step
# >483, c[0.851,44], d[0.000,0.000], g[13.111]
# 1/1 [==============================] - 0s 35ms/step
# >484, c[0.686,62], d[0.000,0.000], g[13.075]
# 1/1 [==============================] - 0s 35ms/step
# >485, c[0.766,38], d[0.000,0.000], g[13.254]
# 1/1 [==============================] - 0s 36ms/step
# >486, c[0.626,56], d[0.000,0.000], g[13.160]
# 1/1 [==============================] - 0s 35ms/step
# >487, c[0.733,25], d[0.000,0.000], g[12.922]
# 1/1 [==============================] - 0s 33ms/step
# >488, c[0.859,44], d[0.000,0.000], g[13.107]
# 1/1 [==============================] - 0s 39ms/step
# >489, c[0.639,56], d[0.000,0.000], g[13.127]
# 1/1 [==============================] - 0s 123ms/step
# >490, c[0.636,69], d[0.000,0.000], g[13.291]
# 1/1 [==============================] - 0s 44ms/step
# >491, c[0.709,50], d[0.000,0.000], g[13.087]
# 1/1 [==============================] - 0s 40ms/step
# >492, c[0.744,56], d[0.000,0.000], g[13.167]
# 1/1 [==============================] - 0s 68ms/step
# >493, c[0.683,56], d[0.000,0.000], g[13.433]
# 1/1 [==============================] - 0s 34ms/step
# >494, c[0.676,56], d[0.000,0.000], g[13.263]
# 1/1 [==============================] - 0s 52ms/step
# >495, c[0.648,56], d[0.000,0.000], g[13.066]
# 1/1 [==============================] - 0s 39ms/step
# >496, c[0.595,62], d[0.000,0.000], g[12.972]
# 1/1 [==============================] - 0s 38ms/step
# >497, c[0.618,75], d[0.000,0.000], g[13.153]
# 1/1 [==============================] - 0s 36ms/step
# >498, c[0.725,44], d[0.000,0.000], g[13.113]
# 1/1 [==============================] - 0s 34ms/step
# ...
# 1/1 [==============================] - 0s 96ms/step
# >17306, c[0.187,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17307, c[0.083,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17308, c[0.050,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 89ms/step
# >17309, c[0.146,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 78ms/step
# >17310, c[0.108,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17311, c[0.046,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17312, c[0.077,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17313, c[0.161,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17314, c[0.472,69], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 84ms/step
# >17315, c[0.238,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17316, c[0.033,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17317, c[0.109,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 95ms/step
# >17318, c[0.073,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 92ms/step
# >17319, c[0.055,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 99ms/step
# >17320, c[0.325,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 95ms/step
# >17321, c[0.291,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 92ms/step
# >17322, c[0.238,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 76ms/step
# >17323, c[0.073,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 94ms/step
# >17324, c[0.174,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 93ms/step
# >17325, c[0.068,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17326, c[0.419,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 119ms/step
# >17327, c[0.118,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17328, c[0.087,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17329, c[0.092,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 95ms/step
# >17330, c[0.035,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 83ms/step
# >17331, c[0.350,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 99ms/step
# >17332, c[0.063,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 99ms/step
# >17333, c[0.334,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 102ms/step
# >17334, c[0.230,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17335, c[0.141,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 80ms/step
# >17336, c[0.108,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17337, c[0.298,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17338, c[0.065,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 85ms/step
# >17339, c[0.088,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17340, c[0.050,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17341, c[0.273,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17342, c[0.137,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 86ms/step
# >17343, c[0.050,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 91ms/step
# >17344, c[0.209,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 89ms/step
# >17345, c[0.177,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 90ms/step
# >17346, c[0.086,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 94ms/step
# >17347, c[0.076,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17348, c[0.067,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 93ms/step
# >17349, c[0.080,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 102ms/step
# >17350, c[0.289,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 79ms/step
# >17351, c[0.190,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17352, c[0.105,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17353, c[0.322,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 82ms/step
# >17354, c[0.380,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17355, c[0.185,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 80ms/step
# >17356, c[0.089,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17357, c[0.134,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 95ms/step
# >17358, c[0.343,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17359, c[0.423,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 94ms/step
# >17360, c[0.123,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17361, c[0.163,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17362, c[0.257,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17363, c[0.173,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 81ms/step
# >17364, c[0.110,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17365, c[0.096,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17366, c[0.302,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17367, c[0.118,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17368, c[0.154,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17369, c[0.254,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17370, c[0.127,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 82ms/step
# >17371, c[0.041,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17372, c[0.307,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 92ms/step
# >17373, c[0.038,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17374, c[0.052,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 81ms/step
# >17375, c[0.471,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 95ms/step
# >17376, c[0.220,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17377, c[0.190,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 95ms/step
# >17378, c[0.356,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 93ms/step
# >17379, c[0.226,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 83ms/step
# >17380, c[0.346,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 98ms/step
# >17381, c[0.102,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17382, c[0.184,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17383, c[0.053,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 94ms/step
# >17384, c[0.365,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 105ms/step
# >17385, c[0.245,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17386, c[0.055,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17387, c[0.181,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17388, c[0.051,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17389, c[0.269,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 99ms/step
# >17390, c[0.147,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17391, c[0.136,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 94ms/step
# >17392, c[0.122,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 81ms/step
# >17393, c[0.337,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 77ms/step
# >17394, c[0.080,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17395, c[0.078,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 92ms/step
# >17396, c[0.105,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 95ms/step
# >17397, c[0.324,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 99ms/step
# >17398, c[0.244,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 82ms/step
# >17399, c[0.136,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 76ms/step
# >17400, c[0.077,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17401, c[0.304,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17402, c[0.228,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 84ms/step
# >17403, c[0.264,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 99ms/step
# >17404, c[0.308,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 84ms/step
# >17405, c[0.278,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17406, c[0.139,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17407, c[0.254,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 79ms/step
# >17408, c[0.147,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17409, c[0.070,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17410, c[0.156,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17411, c[0.073,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 95ms/step
# >17412, c[0.193,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 98ms/step
# >17413, c[0.108,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17414, c[0.121,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17415, c[0.229,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 94ms/step
# >17416, c[0.160,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17417, c[0.059,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 94ms/step
# >17418, c[0.185,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17419, c[0.167,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17420, c[0.381,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 95ms/step
# >17421, c[0.188,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 93ms/step
# >17422, c[0.382,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 98ms/step
# >17423, c[0.264,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17424, c[0.390,75], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17425, c[0.338,75], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17426, c[0.257,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 98ms/step
# >17427, c[0.261,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 109ms/step
# >17428, c[0.304,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 94ms/step
# >17429, c[0.163,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 81ms/step
# >17430, c[0.184,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17431, c[0.194,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 103ms/step
# >17432, c[0.229,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17433, c[0.159,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 102ms/step
# >17434, c[0.179,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 112ms/step
# >17435, c[0.196,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 105ms/step
# >17436, c[0.035,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 99ms/step
# >17437, c[0.234,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 99ms/step
# >17438, c[0.083,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 93ms/step
# >17439, c[0.213,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17440, c[0.109,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 93ms/step
# >17441, c[0.094,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 84ms/step
# >17442, c[0.143,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17443, c[0.331,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 95ms/step
# >17444, c[0.206,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17445, c[0.039,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17446, c[0.209,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 98ms/step
# >17447, c[0.168,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 104ms/step
# >17448, c[0.202,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 83ms/step
# >17449, c[0.129,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 102ms/step
# >17450, c[0.101,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17451, c[0.233,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 99ms/step
# >17452, c[0.160,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 102ms/step
# >17453, c[0.470,75], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17454, c[0.243,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 83ms/step
# >17455, c[0.148,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 88ms/step
# >17456, c[0.259,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17457, c[0.131,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 96ms/step
# >17458, c[0.137,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17459, c[0.233,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 95ms/step
# >17460, c[0.079,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 97ms/step
# >17461, c[0.130,94], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17462, c[0.255,88], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 99ms/step
# >17463, c[0.089,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 101ms/step
# >17464, c[0.233,81], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 100ms/step
# >17465, c[0.056,100], d[0.000,0.000], g[15.425]
# 1/1 [==============================] - 0s 81ms/step
